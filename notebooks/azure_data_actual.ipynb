# %% [markdown]
# #### This file is used for the data processing for the whole parquet file

# %% [markdown]
# #### Instructions before running all the cells:
# 1. Drag the "merged_data_rag.parquet" into the "azure-conversational-assistant" folder
# 2. Install the required packages below

# %%
# !pip install azure-cli pandas openai fastparquet pyarrow
# Out:
# Requirement already satisfied: azure-cli in ./.venv/lib/python3.11/site-packages (2.63.0)
# Requirement already satisfied: pandas in ./.venv/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: openai in ./.venv/lib/python3.11/site-packages (1.37.0)
# Requirement already satisfied: fastparquet in ./.venv/lib/python3.11/site-packages (2024.5.0)
# Requirement already satisfied: pyarrow in ./.venv/lib/python3.11/site-packages (17.0.0)
# Requirement already satisfied: antlr4-python3-runtime~=4.13.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.13.2)
# Requirement already satisfied: azure-appconfiguration~=1.1.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.1.1)
# Requirement already satisfied: azure-batch~=14.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (14.2.0)
# Requirement already satisfied: azure-cli-core==2.63.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.63.0)
# Requirement already satisfied: azure-cosmos>=3.0.2,~=3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (3.2.0)
# Requirement already satisfied: azure-data-tables==12.4.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (12.4.0)
# Requirement already satisfied: azure-datalake-store~=0.0.53 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.0.53)
# Requirement already satisfied: azure-graphrbac~=0.60.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.60.0)
# Requirement already satisfied: azure-keyvault-administration==4.4.0b2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.4.0b2)
# Requirement already satisfied: azure-keyvault-certificates==4.7.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied: azure-keyvault-keys==4.9.0b3 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.9.0b3)
# Requirement already satisfied: azure-keyvault-secrets==4.7.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.7.0)
# Requirement already satisfied: azure-mgmt-advisor==9.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-apimanagement==4.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-appconfiguration==3.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-mgmt-appcontainers==2.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-applicationinsights~=1.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-authorization~=4.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-batchai==7.0.0b1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (7.0.0b1)
# Requirement already satisfied: azure-mgmt-batch~=17.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (17.3.0)
# Requirement already satisfied: azure-mgmt-billing==6.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-botservice~=2.0.0b3 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-cdn==12.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (12.0.0)
# Requirement already satisfied: azure-mgmt-cognitiveservices~=13.5.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (13.5.0)
# Requirement already satisfied: azure-mgmt-compute~=31.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (31.0.0)
# Requirement already satisfied: azure-mgmt-containerinstance==10.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied: azure-mgmt-containerregistry==10.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.3.0)
# Requirement already satisfied: azure-mgmt-containerservice~=31.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (31.0.0)
# Requirement already satisfied: azure-mgmt-cosmosdb==9.5.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.5.1)
# Requirement already satisfied: azure-mgmt-databoxedge~=1.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-datamigration~=10.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied: azure-mgmt-devtestlabs~=4.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-dns~=8.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (8.0.0)
# Requirement already satisfied: azure-mgmt-eventgrid==10.2.0b2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.2.0b2)
# Requirement already satisfied: azure-mgmt-eventhub~=10.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied: azure-mgmt-extendedlocation==1.0.0b2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0b2)
# Requirement already satisfied: azure-mgmt-hdinsight~=9.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-imagebuilder~=1.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.3.0)
# Requirement already satisfied: azure-mgmt-iotcentral~=10.0.0b1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.0.0b2)
# Requirement already satisfied: azure-mgmt-iothub==3.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-mgmt-iothubprovisioningservices==1.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-keyvault==10.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.3.0)
# Requirement already satisfied: azure-mgmt-kusto~=0.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.3.0)
# Requirement already satisfied: azure-mgmt-loganalytics==13.0.0b4 in ./.venv/lib/python3.11/site-packages (from azure-cli) (13.0.0b4)
# Requirement already satisfied: azure-mgmt-managedservices~=1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-managementgroups~=1.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-maps~=2.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-marketplaceordering==1.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-media~=9.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-monitor~=5.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (5.0.1)
# Requirement already satisfied: azure-mgmt-msi~=7.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (7.0.0)
# Requirement already satisfied: azure-mgmt-netapp~=10.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.1.0)
# Requirement already satisfied: azure-mgmt-policyinsights==1.1.0b4 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.1.0b4)
# Requirement already satisfied: azure-mgmt-privatedns~=1.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-rdbms~=10.2.0b16 in ./.venv/lib/python3.11/site-packages (from azure-cli) (10.2.0b17)
# Requirement already satisfied: azure-mgmt-recoveryservicesbackup~=9.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-mgmt-recoveryservices~=3.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-mgmt-redis~=14.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (14.3.0)
# Requirement already satisfied: azure-mgmt-redhatopenshift~=1.4.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.4.0)
# Requirement already satisfied: azure-mgmt-resource==23.1.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (23.1.1)
# Requirement already satisfied: azure-mgmt-search~=9.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-mgmt-security==6.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-servicebus~=8.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (8.2.0)
# Requirement already satisfied: azure-mgmt-servicefabricmanagedclusters==2.0.0b6 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0b6)
# Requirement already satisfied: azure-mgmt-servicelinker==1.2.0b2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.2.0b2)
# Requirement already satisfied: azure-mgmt-servicefabric~=2.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.1.0)
# Requirement already satisfied: azure-mgmt-signalr==2.0.0b1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0b1)
# Requirement already satisfied: azure-mgmt-sqlvirtualmachine==1.0.0b5 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0b5)
# Requirement already satisfied: azure-mgmt-sql==4.0.0b17 in ./.venv/lib/python3.11/site-packages (from azure-cli) (4.0.0b17)
# Requirement already satisfied: azure-mgmt-storage==21.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (21.2.0)
# Requirement already satisfied: azure-mgmt-synapse==2.1.0b5 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.1.0b5)
# Requirement already satisfied: azure-mgmt-trafficmanager~=1.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-web==7.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (7.2.0)
# Requirement already satisfied: azure-monitor-query==1.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied: azure-multiapi-storage~=1.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.2.0)
# Requirement already satisfied: azure-storage-common~=1.4 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.4.2)
# Requirement already satisfied: azure-synapse-accesscontrol~=0.5.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied: azure-synapse-artifacts~=0.19.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.19.0)
# Requirement already satisfied: azure-synapse-managedprivateendpoints~=0.4.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.4.0)
# Requirement already satisfied: azure-synapse-spark~=0.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: chardet~=5.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (5.2.0)
# Requirement already satisfied: colorama~=0.4.4 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.4.6)
# Requirement already satisfied: fabric~=3.2.2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (3.2.2)
# Requirement already satisfied: javaproperties~=0.5.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.5.2)
# Requirement already satisfied: jsondiff~=2.0.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.11/site-packages (from azure-cli) (24.1)
# Requirement already satisfied: pycomposefile>=0.0.29 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.0.31)
# Requirement already satisfied: PyGithub~=1.38 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.59.1)
# Requirement already satisfied: PyNaCl~=1.5.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.5.0)
# Requirement already satisfied: scp~=0.13.2 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.13.6)
# Requirement already satisfied: semver==2.13.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.13.0)
# Requirement already satisfied: six>=1.10.0 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.16.0)
# Requirement already satisfied: sshtunnel~=0.1.4 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.1.5)
# Requirement already satisfied: tabulate in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.9.0)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.11/site-packages (from azure-cli) (2.2.2)
# Requirement already satisfied: websocket-client~=1.3.1 in ./.venv/lib/python3.11/site-packages (from azure-cli) (1.3.3)
# Requirement already satisfied: xmltodict~=0.12 in ./.venv/lib/python3.11/site-packages (from azure-cli) (0.13.0)
# Requirement already satisfied: argcomplete~=3.3.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (3.3.0)
# Requirement already satisfied: azure-cli-telemetry==1.1.0.* in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-core<2,>=1.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.4.0)
# Requirement already satisfied: cryptography in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (43.0.0)
# Requirement already satisfied: humanfriendly~=10.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (10.0)
# Requirement already satisfied: jmespath in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.0.1)
# Requirement already satisfied: knack~=0.11.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (0.11.0)
# Requirement already satisfied: msal-extensions==1.2.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.2.0)
# Requirement already satisfied: msal[broker]==1.30.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.30.0)
# Requirement already satisfied: msrestazure~=0.6.4 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (0.6.4.post1)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (3.4.1)
# Requirement already satisfied: pkginfo>=1.5.0.1 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (1.11.1)
# Requirement already satisfied: PyJWT>=2.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (2.8.0)
# Requirement already satisfied: pyopenssl>=17.1.0 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (24.2.1)
# Requirement already satisfied: requests[socks] in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (2.32.3)
# Requirement already satisfied: psutil>=5.9 in ./.venv/lib/python3.11/site-packages (from azure-cli-core==2.63.0->azure-cli) (5.9.8)
# Requirement already satisfied: azure-core<2.0.0,>=1.15.0 in ./.venv/lib/python3.11/site-packages (from azure-data-tables==12.4.0->azure-cli) (1.30.2)
# Requirement already satisfied: msrest>=0.6.21 in ./.venv/lib/python3.11/site-packages (from azure-data-tables==12.4.0->azure-cli) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in ./.venv/lib/python3.11/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in ./.venv/lib/python3.11/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in ./.venv/lib/python3.11/site-packages (from azure-keyvault-administration==4.4.0b2->azure-cli) (4.12.2)
# Requirement already satisfied: applicationinsights<0.12,>=0.11.1 in ./.venv/lib/python3.11/site-packages (from azure-cli-telemetry==1.1.0.*->azure-cli-core==2.63.0->azure-cli) (0.11.10)
# Requirement already satisfied: portalocker<3,>=1.6 in ./.venv/lib/python3.11/site-packages (from azure-cli-telemetry==1.1.0.*->azure-cli-core==2.63.0->azure-cli) (2.10.1)
# Requirement already satisfied: numpy>=1.23.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.11/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.11/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.11/site-packages (from openai) (4.66.4)
# Requirement already satisfied: cramjam>=2.3 in ./.venv/lib/python3.11/site-packages (from fastparquet) (2.8.3)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.11/site-packages (from fastparquet) (2024.6.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: cffi in ./.venv/lib/python3.11/site-packages (from azure-datalake-store~=0.0.53->azure-cli) (1.16.0)
# Requirement already satisfied: invoke>=2.0 in ./.venv/lib/python3.11/site-packages (from fabric~=3.2.2->azure-cli) (2.2.0)
# Requirement already satisfied: decorator>=5 in ./.venv/lib/python3.11/site-packages (from fabric~=3.2.2->azure-cli) (5.1.1)
# Requirement already satisfied: deprecated>=1.2 in ./.venv/lib/python3.11/site-packages (from fabric~=3.2.2->azure-cli) (1.2.14)
# Requirement already satisfied: certifi in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.11/site-packages (from pycomposefile>=0.0.29->azure-cli) (6.0.2)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.11/site-packages (from cffi->azure-datalake-store~=0.0.53->azure-cli) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.11/site-packages (from deprecated>=1.2->fabric~=3.2.2->azure-cli) (1.16.0)
# Requirement already satisfied: pygments in ./.venv/lib/python3.11/site-packages (from knack~=0.11.0->azure-cli-core==2.63.0->azure-cli) (2.18.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in ./.venv/lib/python3.11/site-packages (from msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (2.0.0)
# Requirement already satisfied: adal<2.0.0,>=0.6.0 in ./.venv/lib/python3.11/site-packages (from msrestazure~=0.6.4->azure-cli-core==2.63.0->azure-cli) (1.2.7)
# Requirement already satisfied: bcrypt>=3.2 in ./.venv/lib/python3.11/site-packages (from paramiko<4.0.0,>=2.0.8->azure-cli-core==2.63.0->azure-cli) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests[socks]->azure-cli-core==2.63.0->azure-cli) (3.3.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in ./.venv/lib/python3.11/site-packages (from requests[socks]->azure-cli-core==2.63.0->azure-cli) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-data-tables==12.4.0->azure-cli) (3.2.2)
#
# [notice] A new release of pip available: 22.3 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import glob
import json
import os

import pandas as pd
from azure.identity import AzureCliCredential, get_bearer_token_provider
from openai import AzureOpenAI
from tqdm import tqdm

# %% [markdown]
# #### Pre-processing the merged parquet file

# %% [markdown]
# ###### 1. Remove articles with 'No HTML Tags' from the 'remove_type' column
# ###### 2. Remove the rows with 'No Extracted Content' from 'remove_type' column
# ###### 3. Remove the rows with 'NaN' from 'remove_type' column
# ###### 4. Remove 'Multilingual' from 'remove_type' column
# ###### 5. Remove the duplicated articles with specific 'id' values
# ###### 6. Remove 'Duplicated Content' from 'remove_type' column, except for specific 'id' values
# ###### 7. Remove the articles that are too lengthy

# %% [markdown]
# ##### Link to the article ids to keep and remove: https://docs.google.com/spreadsheets/d/1PjRx_GkdlNZpV--Ui6sLd0Hvk-3LJ6qk/edit?gid=1214237528#gid=1214237528

# %%
df = pd.read_parquet("merged_data.parquet")

# %%
df[df["remove_type"] == "excel_error"].shape[0]
# Out:
# 0

# %%
df.loc[df["remove_type"] == "No HTML Tags"].shape[0]
# Out:
# 43

# %%
# Remove articles with 'No HTML Tags' from the 'remove_type' column
df = df.loc[df["remove_type"] != "No HTML Tags"]

# %%
df.loc[df["remove_type"] == "No HTML Tags"].shape[0]
# Out:
# 0

# %%
df.loc[df["remove_type"] == "No Extracted Content"].shape[0]
# Out:
# 19

# %%
# Remove the rows with 'No Extracted Content' from 'remove_type' column
df = df[df["remove_type"] != "No Extracted Content"]

# %%
df.loc[df["remove_type"] == "No Extracted Content"].shape[0]
# Out:
# 0

# %%
df.loc[df["remove_type"] == "NaN"].shape[0]
# Out:
# 11

# %%
# Remove the rows with 'NaN' from 'remove_type' column
df = df[df["remove_type"] != "NaN"]

# %%
df.loc[df["remove_type"] == "NaN"].shape[0]
# Out:
# 0

# %%
df.loc[df["remove_type"] == "Multilingual"].shape[0]
# Out:
# 6

# %%
# Remove 'Multilingual' from 'remove_type' column
df = df[df["remove_type"] != "Multilingual"]

# %%
df.loc[df["remove_type"] == "Multilingual"].shape[0]
# Out:
# 0

# %%
df.shape[0]
# Out:
# 2534

# %%
df.loc[df["id"].isin([1444496, 1445828, 1445798, 1444751, 1435183, 1435188, 1434614])]
# Out:
#            id                                       content_name  \
# 621   1444496           Weekend Activities: 5 Ideas for Families
# 1067  1445629                     Sliced Fish with Bee Hoon Soup
# 1215  1443608                                         Mee Goreng
# 2170  1434652             3 Be's To Beat Diabetes | Diabetes Hub
# 2395  1435335  Diabetes Hub: Guide to Managing Diabetes_care-...
# 2396  1435183  Care team resources | Diabetes Hub_care-team-r...
#
#                                          title article_category_names  \
# 621       Outdoor Activities for Your Children  Exercise and Fitness,
# 1067            Sliced Fish with Bee Hoon Soup    Food and Nutrition,
# 1215                                Mee Goreng    Food and Nutrition,
# 2170    3 Be's To Beat Diabetes | Diabetes Hub                   None
# 2395  Diabetes Hub: Guide to Managing Diabetes                   None
# 2396        Care team resources | Diabetes Hub                   None
#
#                                         cover_image_url  \
# 621   https://ch-api.healthhub.sg/api/public/content...
# 1067  https://ch-api.healthhub.sg/api/public/content...
# 1215  https://ch-api.healthhub.sg/api/public/content...
# 2170  https://ch-api.healthhub.sg/api/public/content...
# 2395                                               None
# 2396                                               None
#
#                                                full_url  \
# 621   https://www.healthhub.sg/live-healthy/ideas-fo...
# 1067  https://www.healthhub.sg/live-healthy/fish-bee...
# 1215   https://www.healthhub.sg/live-healthy/mee-goreng
# 2170   https://www.healthhub.sg/programmes/diabetes-hub
# 2395  https://www.healthhub.sg/programmes/diabetes-h...
# 2396  https://www.healthhub.sg/programmes/diabetes-h...
#
#                                               full_url2  \
# 621   www.healthhub.sg/live-healthy/ideas-for-an-act...
# 1067   www.healthhub.sg/live-healthy/fish-bee-hoon-soup
# 1215           www.healthhub.sg/live-healthy/mee-goreng
# 2170           www.healthhub.sg/programmes/diabetes-hub
# 2395  www.healthhub.sg/programmes/diabetes-hub/care-...
# 2396  www.healthhub.sg/programmes/diabetes-hub/care-...
#
#                      friendly_url  \
# 621   ideas-for-an-active-weekend
# 1067           fish-bee-hoon-soup
# 1215                   mee-goreng
# 2170                 diabetes-hub
# 2395          care-team-resources
# 2396          care-team-resources
#
#                                    category_description  \
# 621   You’ve brought your kids to the National Museu...
# 1067       Giving a healthier twist to an old favourite
# 1215  A healthier version of the Singaporean favouri...
# 2170  Come explore 3 easy-to-remember ways to manage...
# 2395  National Diabetes Reference Materials - An ini...
# 2396                 Care team resources | Diabetes Hub
#
#                                            content_body  ...  \
# 621   b'<div class="ExternalClass196D7C5AC7594C8E8BC...  ...
# 1067  b'<div class="ExternalClassF5C1DD3FA7E84963A88...  ...
# 1215  b'<div class="ExternalClass60865CF1F8FA4603ABA...  ...
# 2170  b'<div class="ExternalClassFAC31D10071B445C93D...  ...
# 2395  b'<div class="ExternalClass0F99B891157147D4A5D...  ...
# 2396  b'<div class="ExternalClassFDB7091A35194B5EBBA...  ...
#
#                                  extracted_content_body  \
# 621   The lack of insufficient outdoor activity amon...
# 1067  Mouthwatering sliced fish with bee hoon soup\n...
# 1215  By KK Womens and Childrens Hospital and Ms Hen...
# 2170  3 BE’S TO BEAT DIABETES [/programmes/diabetes-...
# 2395  -  \n Home [#] > Care Team Resources\nCare Tea...
# 2396  _x000D_  _x000D_ _x000D_ _x000D__x000D_ _x000D...
#
#                  l1_mappings               l2_mappings page_views  \
# 621   Well-being & Lifestyle      Exercise and Fitness       2492
# 1067  Well-being & Lifestyle  Food, Diet and Nutrition        789
# 1215  Well-being & Lifestyle  Food, Diet and Nutrition        528
# 2170                    None                      None      40477
# 2395                    None                      None        788
# 2396                    None                      None        788
#
#      engagement_rate  bounce_rate  exit_rate  scroll_percentage  \
# 621         0.948417     0.051583   0.169743           0.311898
# 1067        0.880255     0.119745   0.292776           0.349493
# 1215        0.907919     0.092081   0.215909           0.276042
# 2170        0.688088     0.311912   0.603059           0.363892
# 2395        0.920596     0.079404   0.185279           0.352475
# 2396        0.920596     0.079404   0.185279           0.352475
#
#      percentage_total_views  cumulative_percentage_total_views
# 621                0.001070                           0.646955
# 1067               0.000339                           0.913869
# 1215               0.000227                           0.967905
# 2170               0.013596                           0.902092
# 2395               0.000210                           0.994800
# 2396               0.000210                           0.995010
#
# [6 rows x 39 columns]

# %%
# Remove the duplicated articles with the 'id' = "1445629", "1443608", "1435183", "1435335", "1434652".
df = df[~df["id"].isin([1444496, 1445828, 1445798, 1444751, 1435183, 1435188, 1434614])]

# %%
df.loc[df["id"].isin([1444496, 1445828, 1445798, 1444751, 1435183, 1435188, 1434614])]
# Out:
# Empty DataFrame
# Columns: [id, content_name, title, article_category_names, cover_image_url, full_url, full_url2, friendly_url, category_description, content_body, keywords, feature_title, pr_name, alternate_image_text, date_modified, number_of_views, last_month_view_count, last_two_months_view, content_category, to_remove, remove_type, has_table, has_image, related_sections, extracted_tables, extracted_raw_html_tables, extracted_links, extracted_headers, extracted_images, extracted_content_body, l1_mappings, l2_mappings, page_views, engagement_rate, bounce_rate, exit_rate, scroll_percentage, percentage_total_views, cumulative_percentage_total_views]
# Index: []
#
# [0 rows x 39 columns]

# %%
df.loc[df["id"].isin([1495949, 1445972])]
# Out:
#            id                          content_name  \
# 1420  1497409              conversations-abt-vaping
# 1497  1469472  parents-model-little-habits-everyday
#
#                                                   title  \
# 1420  Parenting Insights: Strategies for Conversatio...
# 1497  Parents Model the Way With Little Habits Every...
#
#      article_category_names cover_image_url  \
# 1420                   None            None
# 1497                   None            None
#
#                                                full_url  \
# 1420  https://www.healthhub.sg/live-healthy/conversa...
# 1497  https://www.healthhub.sg/live-healthy/parents-...
#
#                                               full_url2  \
# 1420  www.healthhub.sg/live-healthy/conversations-ab...
# 1497  www.healthhub.sg/live-healthy/parents-model-li...
#
#                               friendly_url  \
# 1420              conversations-abt-vaping
# 1497  parents-model-little-habits-everyday
#
#                                    category_description  \
# 1420                                               None
# 1497  Pui Yi and her husband inspire their children ...
#
#                                            content_body  ...  \
# 1420  b'<div class="ExternalClassB1D1BA8198604AF5897...  ...
# 1497  b'<h2>Physical Activity Fun Both in and Out of...  ...
#
#                                  extracted_content_body l1_mappings  \
# 1420  Synopsis: Learn proactive parenting strategies...        None
# 1497  Physical Activity Fun Both in and Out of the S...        None
#
#      l2_mappings page_views engagement_rate  bounce_rate  exit_rate  \
# 1420        None        144        0.902985     0.097015   0.222222
# 1497        None         19        0.789474     0.210526   0.315789
#
#       scroll_percentage percentage_total_views  \
# 1420           0.295139               0.000062
# 1497           0.394737               0.000008
#
#       cumulative_percentage_total_views
# 1420                           0.998076
# 1497                           0.999909
#
# [2 rows x 39 columns]

# %%
df.loc[df["remove_type"] == "Duplicated Content"].shape[0]
# Out:
# 17

# %%
df.shape[0]
# Out:
# 2528

# %%
# Remove all the 'Duplicated Content' from 'remove_type' column and only keep the articles with the 'id' = "1497409", "1469472".
df = df[
    (df["remove_type"] != "Duplicated Content")
    | (df["id"].isin([1495949, 1445972, 1446081, 1445629, 1443608, 1445829, 1435335, 1435331, 1434652]))
]

# %%
df.shape[0]
# Out:
# 2511

# %%
# Save the cleaned data to a new parquet file with the name 'merged_data_rag.parquet'
df.to_parquet("merged_data_rag.parquet")

# %%
# Count the data in the 'content_category' column
df["content_category"].value_counts()
# Out:
# content_category
# live-healthy-articles          1148
# medications                     579
# diseases-and-conditions         318
# program-sub-pages               285
# programs                         70
# medical-care-and-facilities      58
# cost-and-financing               24
# health-statistics                15
# support-group-and-others         14
# Name: count, dtype: int64

# %% [markdown]
# #### Read the new RAG parquet file

# %%
df = pd.read_parquet("merged_data_rag.parquet")

# %%
df.shape[0]
# Out:
# 2511

# %%
df
# Out:
#            id                                      content_name  \
# 0     1435040           Breast Screening Subsidies in Singapore
# 1     1435071                   Marriage and Parenthood Schemes
# 2     1434993                                          MediSave
# 3     1435031  Hospital Bills Financial Assistance in Singapore
# 4     1435043   Community Health Assist Scheme (CHAS) Singapore
# ...       ...                                               ...
# 2608  1440763         Heart Failure Transitional Care Programme
# 2609  1440791              Brain and Head Injury Support Groups
# 2610  1440768                      Ambulatory Nutrition Support
# 2611  1440766              LapBandits Support Group (Singapore)
# 2612  1440762              Cardiac Rehabilitation Support Group
#
#                                                  title  \
# 0              Breast Screening Subsidies in Singapore
# 1                      Marriage and Parenthood Schemes
# 2                                             MediSave
# 3     Hospital Bills Financial Assistance in Singapore
# 4      Community Health Assist Scheme (CHAS) Singapore
# ...                                                ...
# 2608         Heart Failure Transitional Care Programme
# 2609              Brain and Head Injury Support Groups
# 2610                      Ambulatory Nutrition Support
# 2611              LapBandits Support Group (Singapore)
# 2612              Cardiac Rehabilitation Support Group
#
#          article_category_names  \
# 0     Conditions and Illnesses,
# 1                    Body Care,
# 2        Alerts and Advisories,
# 3                    Body Care,
# 4        Alerts and Advisories,
# ...                         ...
# 2608  Conditions and Illnesses,
# 2609     Alerts and Advisories,
# 2610  Conditions and Illnesses,
# 2611                 Body Care,
# 2612  Conditions and Illnesses,
#
#                                         cover_image_url  \
# 0     https://ch-api.healthhub.sg/api/public/content...
# 1     https://ch-api.healthhub.sg/api/public/content...
# 2     https://ch-api.healthhub.sg/api/public/content...
# 3     https://ch-api.healthhub.sg/api/public/content...
# 4     https://ch-api.healthhub.sg/api/public/content...
# ...                                                 ...
# 2608  https://ch-api.healthhub.sg/api/public/content...
# 2609  https://ch-api.healthhub.sg/api/public/content...
# 2610  https://ch-api.healthhub.sg/api/public/content...
# 2611  https://ch-api.healthhub.sg/api/public/content...
# 2612  https://ch-api.healthhub.sg/api/public/content...
#
#                                                full_url  \
# 0     https://www.healthhub.sg/a-z/costs-and-financi...
# 1     https://www.healthhub.sg/a-z/costs-and-financi...
# 2     https://www.healthhub.sg/a-z/costs-and-financi...
# 3     https://www.healthhub.sg/a-z/costs-and-financi...
# 4     https://www.healthhub.sg/a-z/costs-and-financi...
# ...                                                 ...
# 2608  https://www.healthhub.sg/a-z/support-groups-an...
# 2609  https://www.healthhub.sg/a-z/support-groups-an...
# 2610  https://www.healthhub.sg/a-z/support-groups-an...
# 2611  https://www.healthhub.sg/a-z/support-groups-an...
# 2612  https://www.healthhub.sg/a-z/support-groups-an...
#
#                                               full_url2  \
# 0     www.healthhub.sg/a-z/costs-and-financing/breas...
# 1     www.healthhub.sg/a-z/costs-and-financing/marri...
# 2     www.healthhub.sg/a-z/costs-and-financing/medisave
# 3     www.healthhub.sg/a-z/costs-and-financing/finan...
# 4         www.healthhub.sg/a-z/costs-and-financing/chas
# ...                                                 ...
# 2608  www.healthhub.sg/a-z/support-groups-and-others...
# 2609  www.healthhub.sg/a-z/support-groups-and-others...
# 2610  www.healthhub.sg/a-z/support-groups-and-others...
# 2611  www.healthhub.sg/a-z/support-groups-and-others...
# 2612  www.healthhub.sg/a-z/support-groups-and-others...
#
#                                            friendly_url  \
# 0                     breast-cancer-screening-subsidies
# 1                            marriage_parenthood_scheme
# 2                                              medisave
# 3     financial-assistance-for-local-patients-in-sin...
# 4                                                  chas
# ...                                                 ...
# 2608      transitional-care-programme-for-heart-failure
# 2609                             2015-NNI-support-group
# 2610                       ambulatory-nutrition-support
# 2611                 singapore-lapbandits-support-group
# 2612  cardiac-rehabilitation-support-group-local-exe...
#
#                                    category_description  \
# 0     Here’s all you need to know about breast cance...
# 1     New parents and couples looking to conceive ca...
# 2     MediSave is the national medical savings schem...
# 3     Having trouble paying your medical bill? Here’...
# 4     With a CHAS card, all Singapore citizens can r...
# ...                                                 ...
# 2608  The team from NUHCS gives support to heart fai...
# 2609  Read on for a list of brain injury support gro...
# 2610  Read about the ambulatory support benefits one...
# 2611  Have you just undergone bariatric surgery for ...
# 2612  Looking to improve your caregiving skills for ...
#
#                                            content_body  ...  \
# 0     b'<div class="ExternalClass07C58E0D957B4AA7B14...  ...
# 1     b'<div class="ExternalClassE1D82270F17241E4955...  ...
# 2     b'<div class="ExternalClass67AD25F1F8B64B349E5...  ...
# 3     b'<div class="ExternalClassE335708125E743FDAA3...  ...
# 4     b'<h2>What is the Community Health Assist Sche...  ...
# ...                                                 ...  ...
# 2608  b'<div class="ExternalClassFC126593610D4F0587A...  ...
# 2609  b'<div class="ExternalClass7C92735B78174928B28...  ...
# 2610  b'<div class="ExternalClass3FABAC9D59A64BCAB96...  ...
# 2611  b'<div class="ExternalClassA4C749C7DB7647FBB6D...  ...
# 2612  b'<div class="ExternalClassD4367205B11F4638BFF...  ...
#
#                                  extracted_content_body      l1_mappings  \
# 0     Breast cancer is the number one cancer among w...  Support & Tools
# 1     MediSave Maternity Package\nWith the MediSave ...             None
# 2     What is MediSave?\nMediSave, introduced in Apr...             None
# 3     Patients or family members who have difficulty...             None
# 4     What is the Community Health Assist Scheme (CH...             None
# ...                                                 ...              ...
# 2608  Heart failure is the leading cause of rehospit...             None
# 2609  Brain Tumour Society (Singapore)\nThe Brain Tu...             None
# 2610  The Importance of Ambulatory Nutrition Support...             None
# 2611  About Khoo Teck Puat Hospitals LapBandits Supp...             None
# 2612  If you are caring for a loved one with cardiov...             None
#
#              l2_mappings page_views engagement_rate  bounce_rate  exit_rate  \
# 0     Cost and Financing      19647        0.790040     0.209960   0.596020
# 1                   None      10173        0.725810     0.274190   0.780104
# 2                   None       5910        0.751147     0.248853   0.576481
# 3                   None       6209        0.788974     0.211026   0.686906
# 4                   None       6057        0.775782     0.224218   0.665016
# ...                  ...        ...             ...          ...        ...
# 2608                None        597        0.936236     0.063764   0.063764
# 2609                None        587        0.949429     0.050571   0.050571
# 2610                None        535        0.962832     0.037168   0.037168
# 2611                None        491        0.964880     0.035120   0.035120
# 2612                None        483        0.977099     0.022901   0.022901
#
#       scroll_percentage percentage_total_views  \
# 0              0.411437               0.207367
# 1              0.394795               0.107372
# 2              0.352073               0.062378
# 3              0.422532               0.065534
# 4              0.405977               0.063929
# ...                 ...                    ...
# 2608           0.314070               0.035043
# 2609           0.293441               0.034456
# 2610           0.295794               0.031404
# 2611           0.273931               0.028821
# 2612           0.283644               0.028352
#
#       cumulative_percentage_total_views
# 0                              0.207367
# 1                              0.314740
# 2                              0.506581
# 3                              0.380273
# 4                              0.444203
# ...                                 ...
# 2608                           0.876966
# 2609                           0.911423
# 2610                           0.942827
# 2611                           0.971648
# 2612                           1.000000
#
# [2511 rows x 39 columns]

# %% [markdown]
# #### Find the number of rows of tables to process

# %%
# Find the number of rows where 'has_table' is True
num_rows_with_table = df[df["has_table"]].shape[0]

print(f"Number of rows with 'has_table' == True: {num_rows_with_table}")
# Out:
# Number of rows with 'has_table' == True: 270

# %% [markdown]
# #### Flag out those articles that exceed input window length by len()

# %%
# # Define the length limit
# length_limit = 100000

# # Set display option to show full URLs without truncation
# pd.set_option('display.max_colwidth', None)

# # Filter and collect IDs, their content lengths, and full URLs
# exceeding_articles = []
# for _, row in df.iterrows():
#     if row['has_table']:
#         content_length = len(row['content_body'])
#         if content_length > length_limit:
#             exceeding_articles.append((
#                 int(row['id']),  # Use 'id' instead of 'article_id'
#                 content_length,
#                 row['full_url']
#             ))

# # Sort the results in descending order by content length
# exceeding_articles_sorted = sorted(exceeding_articles, key=lambda x: x[1], reverse=True)

# # Print the sorted results with full URLs
# print("Article IDs, their content lengths, and full URLs exceeding the length limit:")
# for article_id, content_length, full_url in exceeding_articles_sorted:
#     print(f"Article ID: {article_id}, Length: {content_length}")
#     print(f"Full URL: {full_url}")
#     print('-' * 80)  # Separator line for readability

# # Assuming df1 is your other DataFrame
# # Extract IDs that exceeded the length limit
# exceeding_ids = [article_id for article_id, _, _ in exceeding_articles_sorted]

# # Filter out rows from df1 where 'id' is in the exceeding_ids list
# df1_filtered = df[~df['id'].isin(exceeding_ids)]

# # Optional: Save the filtered DataFrame to a new file if needed
# # output_file_filtered = './data_processing/filtered_df1.parquet'
# # df1_filtered.to_parquet(output_file_filtered)

# print("Filtered df DataFrame where IDs exceeding the length limit have been excluded.")

# %% [markdown]
# #### Filter out those articles that is too lengthy to be processed by LLM due to input window limit

# %%
# Define the article ID to be filtered out
article_id_to_exclude = 1435223

# Filter out the article with the specified ID
df_filtered = df[df["id"] != article_id_to_exclude]

# Get the number of rows in the DataFrame
num_rows = df_filtered.shape[0]

# Print the number of rows
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
# The number of rows in the DataFrame is: 2510

# %% [markdown]
# #### Pass the table content into GPT-4o and create a new parquet with the new column "processed_table_content"

# %%
def ask(html_content: str) -> str:
    azure_credential = AzureCliCredential()
    token_provider = get_bearer_token_provider(azure_credential, "https://cognitiveservices.azure.com/.default")

    openai_client = AzureOpenAI(
        api_version="2024-06-01",
        azure_endpoint="https://apim-jisfkas7teqvm.azure-api.net",
        azure_ad_token_provider=token_provider,
    )

    # Updated prompt to discourage repetition
    prompt = """
    Below is the given full article HTML. Extract the **content of the tables** and their **relevant descriptions** that help understand the tables. 
    Ensure:
    - Retain only essential markdown formatting, such as:
        - **Bold** for headers or important table titles.
        - **Tables** formatted using markdown syntax (e.g., `| Header 1 | Header 2 |`).
    - Avoid unnecessary dashes, bullet points, and extraneous markdown symbols.
    - Remove all other HTML tags.
    - Keep the output concise, accurate, and under 4,000 words. If it exceeds 4,000 words, prioritize summarization.
    - Output the response as a readable markdown string.

    {html_content}
    """

    # Prepare the messages for the API call
    query_messages = [
        {
            "role": "system",
            "content": "You are an AI assistant specialized in extracting structured content from HTML.",
        },
        {"role": "user", "content": prompt.format(html_content=html_content)},
    ]

    response = openai_client.chat.completions.create(
        messages=query_messages,
        model="chat",
        temperature=0.0,
        max_tokens=4096,
        n=1,
        seed=1234,
    )

    return response.choices[0].message.content


# Extract and process HTML tables


def process_html_tables(row):
    if row["has_table"]:
        return ask(row["content_body"])
    return None


# Apply processing to the DataFrame with tqdm for progress tracking
tqdm.pandas()  # Enable progress bar for DataFrame operations
df_filtered["processed_table_content"] = df_filtered.progress_apply(process_html_tables, axis=1)

# Save to a new Parquet file
output_file = "./data_processing/new_index.parquet"
df_filtered.to_parquet(output_file)
# Out:
# /var/folders/xd/bj3151rn7cv92frd9tzmsg4r0000gp/T/ipykernel_6682/879760107.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["processed_table_content"] = df_filtered.apply(process_html_tables, axis=1)

# %% [markdown]
# #### Read the post-processed parquet file

# %%
df1 = pd.read_parquet("data_processing/new_index.parquet")

# %% [markdown]
# #### Find out the length of the post-processed "processed_table_content"

# %%
# Filter rows where 'has_table' is True
df_with_table = df1[df1["has_table"]]

# Add a new column for the character count of 'processed_table_content'
df_with_table["char_count"] = df_with_table["processed_table_content"].apply(lambda x: len(x) if pd.notnull(x) else 0)

# Sort by 'char_count' in descending order and get the top k rows
top_k_longest = df_with_table.sort_values(by="char_count", ascending=False).head(30)

# Display the result
print(top_k_longest[["id", "char_count", "friendly_url"]])

# Count the number of articles with 'char_count' over 5000
articles_over_5000 = df_with_table[df_with_table["char_count"] > 5000].shape[0]

# Display the result
print(f"Number of articles with 'processed_table_content' length over 5000: {articles_over_5000}")
# Out:
#            id  char_count                                       friendly_url
# 950   1445538       17247                             travellersurvivalguide
# 378   1444820       13584                     recommended_dietary_allowances
# 773   1442929       13557                   growing-kid-raising-healthy-kids
# 1073  1445346       10552                          manage_weight_healthy_way
# 2175  1434716       10339                                              IQuit
# 553   1445172       10332            nutrition-for-toddlers-25-36-months-old
# 1705  1440453        9875                        Insulin-Injection-Technique
# 372   1446016        9460  pregnancy-nutrition-during-pregnancy-eating-ri...
# 357   1437940        9422              admissions-and-outpatient-attendances
# 1545  1437970        8562                                       respite_care
# 724   1445669        8334                                babysfirstyearbrain
# 1519  1445673        8164     A Healthy Food Foundation - for Kids and Teens
# 809   1443392        7252                      dont-lose-sleep-over-diabetes
# 6     1434994        6821              subsidies_intermediate_long_term_care
# 2218  1434622        6794                    national-steps-challenge-campus
# 215   1437766        6596                           Heart-Failure-Medication
# 496   1444852        6431                                brown_rice_paradise
# 2189  1434624        6403                                           StayWell
# 10    1435059        6377                                        eldershield
# 1092  1445311        6321              debunking-5-myths-of-fertility-health
# 1740  1471768        6319                                        Anti-Nausea
# 423   1445959        6298                            guide_your_growing_baby
# 1869  1440474        6213                         Diabetes-Treatment-Tablets
# 355   1437942        6196                                    health-manpower
# 1015  1445724        6118                             Type-2-Screening-tests
# 1558  1439074        5755                              your-hospital-journey
# 1     1435071        5623                         marriage_parenthood_scheme
# 396   1445479        5620                health_screening_for_primary_school
# 696   1445386        5579                                   end_of_life_care
# 1755  1440237        5502                          Vaginal-Estradiol-Vagifem
# Number of articles with 'processed_table_content' length over 5000: 41
# /var/folders/xd/bj3151rn7cv92frd9tzmsg4r0000gp/T/ipykernel_6682/1384592369.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_table["char_count"] = df_with_table["processed_table_content"].apply(lambda x: len(x) if pd.notnull(x) else 0)

# %% [markdown]
# #### Inspect the top k articles post-processed "processed_table_content"

# %%
# # Step 2: Filter the DataFrame by the specific IDs
# filtered_df = df1[df1['id'].isin([1439448, 1445517])]

# # Step 3: Extract the 'processed_table_content' column for the selected rows
# content_1439448 = filtered_df[filtered_df['id'] == 1439448]['processed_table_content'].values[0]
# content_1445517 = filtered_df[filtered_df['id'] == 1445517]['processed_table_content'].values[0]

# # Step 4: Write the content to a .txt file
# with open("processed_content_1439448.txt", "w") as file1:
#     file1.write(content_1439448)

# with open("processed_content_1445517.txt", "w") as file2:
#     file2.write(content_1445517)

# print("Files saved successfully.")
# Out:
# Files saved successfully.

# %% [markdown]
# #### Manually curate the content to ensure the quality of the data for ingestion into the search index

# %%
# # Step 2: Define the new content for each ID
# new_content_1439448 = """
# **Week 3 of the pack:**

# | No missed tablets in the last 7 days | Take the missed tablet as soon as remembered, even if it means taking 2 tablets at the same time. Continue to take your tablets at your usual time and start the next pack right away without the 7-day tablet free period or 7-day white (inactive) tablets i.e. no gap should be left between packs. Your menses may not come until the next pack is finished, but there is no need to worry. However, if your menses do not occur after the next pack is finished, you should take a pregnancy test to make sure you are not pregnant. OR Stop taking medication from the current pack for 7 days (7-day tablet-free period). A withdrawal bleed (menses) usually occurs and then start a next pack after 7 days. |
# """

# new_content_1445517 = """
# **Suggestions for Overcoming Physical Activity Barriers**

# | Lack of time | Monitor your daily activities for one week. Identify available time slots where you can get at least 10 minutes of aerobic type physical activity. Add physical activity to your daily routine. Walk or ride your bicycle to work or to the shops, and organise your daily activities around physical activity. E.g. walk the dog, exercise while you watch TV, park farther away from your destination. Select activities requiring minimal time, such as walking, jogging or stair climbing. |
# """

# # Step 3: Update the 'processed_table_content' for the given IDs
# df1.loc[df1['id'] == 1439448, 'processed_table_content'] = new_content_1439448
# df1.loc[df1['id'] == 1445517, 'processed_table_content'] = new_content_1445517

# # Step 4: Save the updated DataFrame to a new Parquet file
# df1.to_parquet("data_processing/new_index.parquet")

# print("Updated content and saved to Parquet file successfully.")
# Out:
# Updated content and saved to Parquet file successfully.

# %% [markdown]
# #### Extract out the "content_body" as a .txt file to verify extraction

# %%
# Filter the DataFrame for rows where 'has_table' is True
filtered_df1 = df1[df1["has_table"]]

# Ensure the raw_content_body directory exists
raw_content_dir = "./data_processing/raw_content_body"
os.makedirs(raw_content_dir, exist_ok=True)

# Process each article ID
for article_id in filtered_df1["id"].unique():
    # Filter the DataFrame for the current article ID
    article_df = filtered_df1[filtered_df1["id"] == article_id]

    # Extract the 'content_body' column
    processed_content = article_df["content_body"].tolist()

    # Define the output file path
    output_txt_file = f"{raw_content_dir}/raw_article_{article_id}.txt"

    # Write the content to a text file
    with open(output_txt_file, "w") as file:
        for content in processed_content:
            # Check if content is in bytes and decode if necessary
            if isinstance(content, bytes):
                content = content.decode("utf-8")
            file.write(content + "\n")  # Write each entry on a new line

    print(f"Raw content body for article {article_id} saved to {output_txt_file}")
# Out:
# Raw content body for article 1435040 saved to ./data_processing/raw_content_body/raw_article_1435040.txt
# Raw content body for article 1435071 saved to ./data_processing/raw_content_body/raw_article_1435071.txt
# Raw content body for article 1435043 saved to ./data_processing/raw_content_body/raw_article_1435043.txt
# Raw content body for article 1435005 saved to ./data_processing/raw_content_body/raw_article_1435005.txt
# Raw content body for article 1434994 saved to ./data_processing/raw_content_body/raw_article_1434994.txt
# Raw content body for article 1435059 saved to ./data_processing/raw_content_body/raw_article_1435059.txt
# Raw content body for article 1435029 saved to ./data_processing/raw_content_body/raw_article_1435029.txt
# Raw content body for article 1434998 saved to ./data_processing/raw_content_body/raw_article_1434998.txt
# Raw content body for article 1437795 saved to ./data_processing/raw_content_body/raw_article_1437795.txt
# Raw content body for article 1437742 saved to ./data_processing/raw_content_body/raw_article_1437742.txt
# Raw content body for article 1437786 saved to ./data_processing/raw_content_body/raw_article_1437786.txt
# Raw content body for article 1437477 saved to ./data_processing/raw_content_body/raw_article_1437477.txt
# Raw content body for article 1437357 saved to ./data_processing/raw_content_body/raw_article_1437357.txt
# Raw content body for article 1437751 saved to ./data_processing/raw_content_body/raw_article_1437751.txt
# Raw content body for article 1437629 saved to ./data_processing/raw_content_body/raw_article_1437629.txt
# Raw content body for article 1437583 saved to ./data_processing/raw_content_body/raw_article_1437583.txt
# Raw content body for article 1437890 saved to ./data_processing/raw_content_body/raw_article_1437890.txt
# Raw content body for article 1437423 saved to ./data_processing/raw_content_body/raw_article_1437423.txt
# Raw content body for article 1437794 saved to ./data_processing/raw_content_body/raw_article_1437794.txt
# Raw content body for article 1437587 saved to ./data_processing/raw_content_body/raw_article_1437587.txt
# Raw content body for article 1437331 saved to ./data_processing/raw_content_body/raw_article_1437331.txt
# Raw content body for article 1437338 saved to ./data_processing/raw_content_body/raw_article_1437338.txt
# Raw content body for article 1437888 saved to ./data_processing/raw_content_body/raw_article_1437888.txt
# Raw content body for article 1437593 saved to ./data_processing/raw_content_body/raw_article_1437593.txt
# Raw content body for article 1437766 saved to ./data_processing/raw_content_body/raw_article_1437766.txt
# Raw content body for article 1437353 saved to ./data_processing/raw_content_body/raw_article_1437353.txt
# Raw content body for article 1437712 saved to ./data_processing/raw_content_body/raw_article_1437712.txt
# Raw content body for article 1437856 saved to ./data_processing/raw_content_body/raw_article_1437856.txt
# Raw content body for article 1464135 saved to ./data_processing/raw_content_body/raw_article_1464135.txt
# Raw content body for article 1437760 saved to ./data_processing/raw_content_body/raw_article_1437760.txt
# Raw content body for article 1437960 saved to ./data_processing/raw_content_body/raw_article_1437960.txt
# Raw content body for article 1437954 saved to ./data_processing/raw_content_body/raw_article_1437954.txt
# Raw content body for article 1437958 saved to ./data_processing/raw_content_body/raw_article_1437958.txt
# Raw content body for article 1437942 saved to ./data_processing/raw_content_body/raw_article_1437942.txt
# Raw content body for article 1437956 saved to ./data_processing/raw_content_body/raw_article_1437956.txt
# Raw content body for article 1437940 saved to ./data_processing/raw_content_body/raw_article_1437940.txt
# Raw content body for article 1437962 saved to ./data_processing/raw_content_body/raw_article_1437962.txt
# Raw content body for article 1437964 saved to ./data_processing/raw_content_body/raw_article_1437964.txt
# Raw content body for article 1437938 saved to ./data_processing/raw_content_body/raw_article_1437938.txt
# Raw content body for article 1437946 saved to ./data_processing/raw_content_body/raw_article_1437946.txt
# Raw content body for article 1437950 saved to ./data_processing/raw_content_body/raw_article_1437950.txt
# Raw content body for article 1437966 saved to ./data_processing/raw_content_body/raw_article_1437966.txt
# Raw content body for article 1437952 saved to ./data_processing/raw_content_body/raw_article_1437952.txt
# Raw content body for article 1437948 saved to ./data_processing/raw_content_body/raw_article_1437948.txt
# Raw content body for article 1437944 saved to ./data_processing/raw_content_body/raw_article_1437944.txt
# Raw content body for article 1445137 saved to ./data_processing/raw_content_body/raw_article_1445137.txt
# Raw content body for article 1445282 saved to ./data_processing/raw_content_body/raw_article_1445282.txt
# Raw content body for article 1446016 saved to ./data_processing/raw_content_body/raw_article_1446016.txt
# Raw content body for article 1445852 saved to ./data_processing/raw_content_body/raw_article_1445852.txt
# Raw content body for article 1443987 saved to ./data_processing/raw_content_body/raw_article_1443987.txt
# Raw content body for article 1444820 saved to ./data_processing/raw_content_body/raw_article_1444820.txt
# Raw content body for article 1444912 saved to ./data_processing/raw_content_body/raw_article_1444912.txt
# Raw content body for article 1445136 saved to ./data_processing/raw_content_body/raw_article_1445136.txt
# Raw content body for article 1442923 saved to ./data_processing/raw_content_body/raw_article_1442923.txt
# Raw content body for article 1442691 saved to ./data_processing/raw_content_body/raw_article_1442691.txt
# Raw content body for article 1445148 saved to ./data_processing/raw_content_body/raw_article_1445148.txt
# Raw content body for article 1445479 saved to ./data_processing/raw_content_body/raw_article_1445479.txt
# Raw content body for article 1442502 saved to ./data_processing/raw_content_body/raw_article_1442502.txt
# Raw content body for article 1445643 saved to ./data_processing/raw_content_body/raw_article_1445643.txt
# Raw content body for article 1442421 saved to ./data_processing/raw_content_body/raw_article_1442421.txt
# Raw content body for article 1445277 saved to ./data_processing/raw_content_body/raw_article_1445277.txt
# Raw content body for article 1445178 saved to ./data_processing/raw_content_body/raw_article_1445178.txt
# Raw content body for article 1446031 saved to ./data_processing/raw_content_body/raw_article_1446031.txt
# Raw content body for article 1443701 saved to ./data_processing/raw_content_body/raw_article_1443701.txt
# Raw content body for article 1443584 saved to ./data_processing/raw_content_body/raw_article_1443584.txt
# Raw content body for article 1445042 saved to ./data_processing/raw_content_body/raw_article_1445042.txt
# Raw content body for article 1445959 saved to ./data_processing/raw_content_body/raw_article_1445959.txt
# Raw content body for article 1445505 saved to ./data_processing/raw_content_body/raw_article_1445505.txt
# Raw content body for article 1445162 saved to ./data_processing/raw_content_body/raw_article_1445162.txt
# Raw content body for article 1445484 saved to ./data_processing/raw_content_body/raw_article_1445484.txt
# Raw content body for article 1446066 saved to ./data_processing/raw_content_body/raw_article_1446066.txt
# Raw content body for article 1445167 saved to ./data_processing/raw_content_body/raw_article_1445167.txt
# Raw content body for article 1445447 saved to ./data_processing/raw_content_body/raw_article_1445447.txt
# Raw content body for article 1444056 saved to ./data_processing/raw_content_body/raw_article_1444056.txt
# Raw content body for article 1442782 saved to ./data_processing/raw_content_body/raw_article_1442782.txt
# Raw content body for article 1445144 saved to ./data_processing/raw_content_body/raw_article_1445144.txt
# Raw content body for article 1443088 saved to ./data_processing/raw_content_body/raw_article_1443088.txt
# Raw content body for article 1444565 saved to ./data_processing/raw_content_body/raw_article_1444565.txt
# Raw content body for article 1444852 saved to ./data_processing/raw_content_body/raw_article_1444852.txt
# Raw content body for article 1442686 saved to ./data_processing/raw_content_body/raw_article_1442686.txt
# Raw content body for article 1445143 saved to ./data_processing/raw_content_body/raw_article_1445143.txt
# Raw content body for article 1445899 saved to ./data_processing/raw_content_body/raw_article_1445899.txt
# Raw content body for article 1443475 saved to ./data_processing/raw_content_body/raw_article_1443475.txt
# Raw content body for article 1445147 saved to ./data_processing/raw_content_body/raw_article_1445147.txt
# Raw content body for article 1445689 saved to ./data_processing/raw_content_body/raw_article_1445689.txt
# Raw content body for article 1445859 saved to ./data_processing/raw_content_body/raw_article_1445859.txt
# Raw content body for article 1445172 saved to ./data_processing/raw_content_body/raw_article_1445172.txt
# Raw content body for article 1442681 saved to ./data_processing/raw_content_body/raw_article_1442681.txt
# Raw content body for article 1442755 saved to ./data_processing/raw_content_body/raw_article_1442755.txt
# Raw content body for article 1445117 saved to ./data_processing/raw_content_body/raw_article_1445117.txt
# Raw content body for article 1445603 saved to ./data_processing/raw_content_body/raw_article_1445603.txt
# Raw content body for article 1443082 saved to ./data_processing/raw_content_body/raw_article_1443082.txt
# Raw content body for article 1446045 saved to ./data_processing/raw_content_body/raw_article_1446045.txt
# Raw content body for article 1442571 saved to ./data_processing/raw_content_body/raw_article_1442571.txt
# Raw content body for article 1442456 saved to ./data_processing/raw_content_body/raw_article_1442456.txt
# Raw content body for article 1443393 saved to ./data_processing/raw_content_body/raw_article_1443393.txt
# Raw content body for article 1442664 saved to ./data_processing/raw_content_body/raw_article_1442664.txt
# Raw content body for article 1445568 saved to ./data_processing/raw_content_body/raw_article_1445568.txt
# Raw content body for article 1445862 saved to ./data_processing/raw_content_body/raw_article_1445862.txt
# Raw content body for article 1443323 saved to ./data_processing/raw_content_body/raw_article_1443323.txt
# Raw content body for article 1443020 saved to ./data_processing/raw_content_body/raw_article_1443020.txt
# Raw content body for article 1445386 saved to ./data_processing/raw_content_body/raw_article_1445386.txt
# Raw content body for article 1445854 saved to ./data_processing/raw_content_body/raw_article_1445854.txt
# Raw content body for article 1442545 saved to ./data_processing/raw_content_body/raw_article_1442545.txt
# Raw content body for article 1445777 saved to ./data_processing/raw_content_body/raw_article_1445777.txt
# Raw content body for article 1445774 saved to ./data_processing/raw_content_body/raw_article_1445774.txt
# Raw content body for article 1445669 saved to ./data_processing/raw_content_body/raw_article_1445669.txt
# Raw content body for article 1443351 saved to ./data_processing/raw_content_body/raw_article_1443351.txt
# Raw content body for article 1445456 saved to ./data_processing/raw_content_body/raw_article_1445456.txt
# Raw content body for article 1442509 saved to ./data_processing/raw_content_body/raw_article_1442509.txt
# Raw content body for article 1445738 saved to ./data_processing/raw_content_body/raw_article_1445738.txt
# Raw content body for article 1443094 saved to ./data_processing/raw_content_body/raw_article_1443094.txt
# Raw content body for article 1442785 saved to ./data_processing/raw_content_body/raw_article_1442785.txt
# Raw content body for article 1442929 saved to ./data_processing/raw_content_body/raw_article_1442929.txt
# Raw content body for article 1484558 saved to ./data_processing/raw_content_body/raw_article_1484558.txt
# Raw content body for article 1445911 saved to ./data_processing/raw_content_body/raw_article_1445911.txt
# Raw content body for article 1445517 saved to ./data_processing/raw_content_body/raw_article_1445517.txt
# Raw content body for article 1445898 saved to ./data_processing/raw_content_body/raw_article_1445898.txt
# Raw content body for article 1445330 saved to ./data_processing/raw_content_body/raw_article_1445330.txt
# Raw content body for article 1444615 saved to ./data_processing/raw_content_body/raw_article_1444615.txt
# Raw content body for article 1443392 saved to ./data_processing/raw_content_body/raw_article_1443392.txt
# Raw content body for article 1444566 saved to ./data_processing/raw_content_body/raw_article_1444566.txt
# Raw content body for article 1442550 saved to ./data_processing/raw_content_body/raw_article_1442550.txt
# Raw content body for article 1445620 saved to ./data_processing/raw_content_body/raw_article_1445620.txt
# Raw content body for article 1445937 saved to ./data_processing/raw_content_body/raw_article_1445937.txt
# Raw content body for article 1445668 saved to ./data_processing/raw_content_body/raw_article_1445668.txt
# Raw content body for article 1442667 saved to ./data_processing/raw_content_body/raw_article_1442667.txt
# Raw content body for article 1442464 saved to ./data_processing/raw_content_body/raw_article_1442464.txt
# Raw content body for article 1445850 saved to ./data_processing/raw_content_body/raw_article_1445850.txt
# Raw content body for article 1445538 saved to ./data_processing/raw_content_body/raw_article_1445538.txt
# Raw content body for article 1443557 saved to ./data_processing/raw_content_body/raw_article_1443557.txt
# Raw content body for article 1445213 saved to ./data_processing/raw_content_body/raw_article_1445213.txt
# Raw content body for article 1445088 saved to ./data_processing/raw_content_body/raw_article_1445088.txt
# Raw content body for article 1442928 saved to ./data_processing/raw_content_body/raw_article_1442928.txt
# Raw content body for article 1444303 saved to ./data_processing/raw_content_body/raw_article_1444303.txt
# Raw content body for article 1445711 saved to ./data_processing/raw_content_body/raw_article_1445711.txt
# Raw content body for article 1443054 saved to ./data_processing/raw_content_body/raw_article_1443054.txt
# Raw content body for article 1445582 saved to ./data_processing/raw_content_body/raw_article_1445582.txt
# Raw content body for article 1443389 saved to ./data_processing/raw_content_body/raw_article_1443389.txt
# Raw content body for article 1445724 saved to ./data_processing/raw_content_body/raw_article_1445724.txt
# Raw content body for article 1445622 saved to ./data_processing/raw_content_body/raw_article_1445622.txt
# Raw content body for article 1444065 saved to ./data_processing/raw_content_body/raw_article_1444065.txt
# Raw content body for article 1443042 saved to ./data_processing/raw_content_body/raw_article_1443042.txt
# Raw content body for article 1442765 saved to ./data_processing/raw_content_body/raw_article_1442765.txt
# Raw content body for article 1445346 saved to ./data_processing/raw_content_body/raw_article_1445346.txt
# Raw content body for article 1445917 saved to ./data_processing/raw_content_body/raw_article_1445917.txt
# Raw content body for article 1443310 saved to ./data_processing/raw_content_body/raw_article_1443310.txt
# Raw content body for article 1445311 saved to ./data_processing/raw_content_body/raw_article_1445311.txt
# Raw content body for article 1445204 saved to ./data_processing/raw_content_body/raw_article_1445204.txt
# Raw content body for article 1445681 saved to ./data_processing/raw_content_body/raw_article_1445681.txt
# Raw content body for article 1442510 saved to ./data_processing/raw_content_body/raw_article_1442510.txt
# Raw content body for article 1443043 saved to ./data_processing/raw_content_body/raw_article_1443043.txt
# Raw content body for article 1442654 saved to ./data_processing/raw_content_body/raw_article_1442654.txt
# Raw content body for article 1444658 saved to ./data_processing/raw_content_body/raw_article_1444658.txt
# Raw content body for article 1442339 saved to ./data_processing/raw_content_body/raw_article_1442339.txt
# Raw content body for article 1445616 saved to ./data_processing/raw_content_body/raw_article_1445616.txt
# Raw content body for article 1445956 saved to ./data_processing/raw_content_body/raw_article_1445956.txt
# Raw content body for article 1445618 saved to ./data_processing/raw_content_body/raw_article_1445618.txt
# Raw content body for article 1444879 saved to ./data_processing/raw_content_body/raw_article_1444879.txt
# Raw content body for article 1445613 saved to ./data_processing/raw_content_body/raw_article_1445613.txt
# Raw content body for article 1445607 saved to ./data_processing/raw_content_body/raw_article_1445607.txt
# Raw content body for article 1445611 saved to ./data_processing/raw_content_body/raw_article_1445611.txt
# Raw content body for article 1445485 saved to ./data_processing/raw_content_body/raw_article_1445485.txt
# Raw content body for article 1445707 saved to ./data_processing/raw_content_body/raw_article_1445707.txt
# Raw content body for article 1445599 saved to ./data_processing/raw_content_body/raw_article_1445599.txt
# Raw content body for article 1445291 saved to ./data_processing/raw_content_body/raw_article_1445291.txt
# Raw content body for article 1442577 saved to ./data_processing/raw_content_body/raw_article_1442577.txt
# Raw content body for article 1445605 saved to ./data_processing/raw_content_body/raw_article_1445605.txt
# Raw content body for article 1445608 saved to ./data_processing/raw_content_body/raw_article_1445608.txt
# Raw content body for article 1445460 saved to ./data_processing/raw_content_body/raw_article_1445460.txt
# Raw content body for article 1445673 saved to ./data_processing/raw_content_body/raw_article_1445673.txt
# Raw content body for article 1445601 saved to ./data_processing/raw_content_body/raw_article_1445601.txt
# Raw content body for article 1437992 saved to ./data_processing/raw_content_body/raw_article_1437992.txt
# Raw content body for article 1438002 saved to ./data_processing/raw_content_body/raw_article_1438002.txt
# Raw content body for article 1439046 saved to ./data_processing/raw_content_body/raw_article_1439046.txt
# Raw content body for article 1439058 saved to ./data_processing/raw_content_body/raw_article_1439058.txt
# Raw content body for article 1437995 saved to ./data_processing/raw_content_body/raw_article_1437995.txt
# Raw content body for article 1439066 saved to ./data_processing/raw_content_body/raw_article_1439066.txt
# Raw content body for article 1438730 saved to ./data_processing/raw_content_body/raw_article_1438730.txt
# Raw content body for article 1439070 saved to ./data_processing/raw_content_body/raw_article_1439070.txt
# Raw content body for article 1437970 saved to ./data_processing/raw_content_body/raw_article_1437970.txt
# Raw content body for article 1438375 saved to ./data_processing/raw_content_body/raw_article_1438375.txt
# Raw content body for article 1439074 saved to ./data_processing/raw_content_body/raw_article_1439074.txt
# Raw content body for article 1439989 saved to ./data_processing/raw_content_body/raw_article_1439989.txt
# Raw content body for article 1439448 saved to ./data_processing/raw_content_body/raw_article_1439448.txt
# Raw content body for article 1440653 saved to ./data_processing/raw_content_body/raw_article_1440653.txt
# Raw content body for article 1440492 saved to ./data_processing/raw_content_body/raw_article_1440492.txt
# Raw content body for article 1440166 saved to ./data_processing/raw_content_body/raw_article_1440166.txt
# Raw content body for article 1440254 saved to ./data_processing/raw_content_body/raw_article_1440254.txt
# Raw content body for article 1439835 saved to ./data_processing/raw_content_body/raw_article_1439835.txt
# Raw content body for article 1439849 saved to ./data_processing/raw_content_body/raw_article_1439849.txt
# Raw content body for article 1440233 saved to ./data_processing/raw_content_body/raw_article_1440233.txt
# Raw content body for article 1440230 saved to ./data_processing/raw_content_body/raw_article_1440230.txt
# Raw content body for article 1440238 saved to ./data_processing/raw_content_body/raw_article_1440238.txt
# Raw content body for article 1439800 saved to ./data_processing/raw_content_body/raw_article_1439800.txt
# Raw content body for article 1471925 saved to ./data_processing/raw_content_body/raw_article_1471925.txt
# Raw content body for article 1439589 saved to ./data_processing/raw_content_body/raw_article_1439589.txt
# Raw content body for article 1440258 saved to ./data_processing/raw_content_body/raw_article_1440258.txt
# Raw content body for article 1439975 saved to ./data_processing/raw_content_body/raw_article_1439975.txt
# Raw content body for article 1440453 saved to ./data_processing/raw_content_body/raw_article_1440453.txt
# Raw content body for article 1439798 saved to ./data_processing/raw_content_body/raw_article_1439798.txt
# Raw content body for article 1471768 saved to ./data_processing/raw_content_body/raw_article_1471768.txt
# Raw content body for article 1440237 saved to ./data_processing/raw_content_body/raw_article_1440237.txt
# Raw content body for article 1440457 saved to ./data_processing/raw_content_body/raw_article_1440457.txt
# Raw content body for article 1440408 saved to ./data_processing/raw_content_body/raw_article_1440408.txt
# Raw content body for article 1498738 saved to ./data_processing/raw_content_body/raw_article_1498738.txt
# Raw content body for article 1470581 saved to ./data_processing/raw_content_body/raw_article_1470581.txt
# Raw content body for article 1439839 saved to ./data_processing/raw_content_body/raw_article_1439839.txt
# Raw content body for article 1439777 saved to ./data_processing/raw_content_body/raw_article_1439777.txt
# Raw content body for article 1439952 saved to ./data_processing/raw_content_body/raw_article_1439952.txt
# Raw content body for article 1439226 saved to ./data_processing/raw_content_body/raw_article_1439226.txt
# Raw content body for article 1440434 saved to ./data_processing/raw_content_body/raw_article_1440434.txt
# Raw content body for article 1439887 saved to ./data_processing/raw_content_body/raw_article_1439887.txt
# Raw content body for article 1477242 saved to ./data_processing/raw_content_body/raw_article_1477242.txt
# Raw content body for article 1440474 saved to ./data_processing/raw_content_body/raw_article_1440474.txt
# Raw content body for article 1439803 saved to ./data_processing/raw_content_body/raw_article_1439803.txt
# Raw content body for article 1440432 saved to ./data_processing/raw_content_body/raw_article_1440432.txt
# Raw content body for article 1485623 saved to ./data_processing/raw_content_body/raw_article_1485623.txt
# Raw content body for article 1439758 saved to ./data_processing/raw_content_body/raw_article_1439758.txt
# Raw content body for article 1440406 saved to ./data_processing/raw_content_body/raw_article_1440406.txt
# Raw content body for article 1485631 saved to ./data_processing/raw_content_body/raw_article_1485631.txt
# Raw content body for article 1485693 saved to ./data_processing/raw_content_body/raw_article_1485693.txt
# Raw content body for article 1439769 saved to ./data_processing/raw_content_body/raw_article_1439769.txt
# Raw content body for article 1470789 saved to ./data_processing/raw_content_body/raw_article_1470789.txt
# Raw content body for article 1440262 saved to ./data_processing/raw_content_body/raw_article_1440262.txt
# Raw content body for article 1498740 saved to ./data_processing/raw_content_body/raw_article_1498740.txt
# Raw content body for article 1499904 saved to ./data_processing/raw_content_body/raw_article_1499904.txt
# Raw content body for article 1485685 saved to ./data_processing/raw_content_body/raw_article_1485685.txt
# Raw content body for article 1499902 saved to ./data_processing/raw_content_body/raw_article_1499902.txt
# Raw content body for article 1499906 saved to ./data_processing/raw_content_body/raw_article_1499906.txt
# Raw content body for article 1499891 saved to ./data_processing/raw_content_body/raw_article_1499891.txt
# Raw content body for article 1499898 saved to ./data_processing/raw_content_body/raw_article_1499898.txt
# Raw content body for article 1440511 saved to ./data_processing/raw_content_body/raw_article_1440511.txt
# Raw content body for article 1440529 saved to ./data_processing/raw_content_body/raw_article_1440529.txt
# Raw content body for article 1434612 saved to ./data_processing/raw_content_body/raw_article_1434612.txt
# Raw content body for article 1434580 saved to ./data_processing/raw_content_body/raw_article_1434580.txt
# Raw content body for article 1453207 saved to ./data_processing/raw_content_body/raw_article_1453207.txt
# Raw content body for article 1434596 saved to ./data_processing/raw_content_body/raw_article_1434596.txt
# Raw content body for article 1434716 saved to ./data_processing/raw_content_body/raw_article_1434716.txt
# Raw content body for article 1434574 saved to ./data_processing/raw_content_body/raw_article_1434574.txt
# Raw content body for article 1462073 saved to ./data_processing/raw_content_body/raw_article_1462073.txt
# Raw content body for article 1434624 saved to ./data_processing/raw_content_body/raw_article_1434624.txt
# Raw content body for article 1434604 saved to ./data_processing/raw_content_body/raw_article_1434604.txt
# Raw content body for article 1434670 saved to ./data_processing/raw_content_body/raw_article_1434670.txt
# Raw content body for article 1434570 saved to ./data_processing/raw_content_body/raw_article_1434570.txt
# Raw content body for article 1434602 saved to ./data_processing/raw_content_body/raw_article_1434602.txt
# Raw content body for article 1434608 saved to ./data_processing/raw_content_body/raw_article_1434608.txt
# Raw content body for article 1434626 saved to ./data_processing/raw_content_body/raw_article_1434626.txt
# Raw content body for article 1434622 saved to ./data_processing/raw_content_body/raw_article_1434622.txt
# Raw content body for article 1434630 saved to ./data_processing/raw_content_body/raw_article_1434630.txt
# Raw content body for article 1434594 saved to ./data_processing/raw_content_body/raw_article_1434594.txt
# Raw content body for article 1435221 saved to ./data_processing/raw_content_body/raw_article_1435221.txt
# Raw content body for article 1434809 saved to ./data_processing/raw_content_body/raw_article_1434809.txt
# Raw content body for article 1434811 saved to ./data_processing/raw_content_body/raw_article_1434811.txt
# Raw content body for article 1435231 saved to ./data_processing/raw_content_body/raw_article_1435231.txt
# Raw content body for article 1435240 saved to ./data_processing/raw_content_body/raw_article_1435240.txt
# Raw content body for article 1434892 saved to ./data_processing/raw_content_body/raw_article_1434892.txt
# Raw content body for article 1434857 saved to ./data_processing/raw_content_body/raw_article_1434857.txt
# Raw content body for article 1434803 saved to ./data_processing/raw_content_body/raw_article_1434803.txt
# Raw content body for article 1435083 saved to ./data_processing/raw_content_body/raw_article_1435083.txt
# Raw content body for article 1434899 saved to ./data_processing/raw_content_body/raw_article_1434899.txt
# Raw content body for article 1434823 saved to ./data_processing/raw_content_body/raw_article_1434823.txt
# Raw content body for article 1434821 saved to ./data_processing/raw_content_body/raw_article_1434821.txt
# Raw content body for article 1434867 saved to ./data_processing/raw_content_body/raw_article_1434867.txt
# Raw content body for article 1434865 saved to ./data_processing/raw_content_body/raw_article_1434865.txt
# Raw content body for article 1435313 saved to ./data_processing/raw_content_body/raw_article_1435313.txt
# Raw content body for article 1440770 saved to ./data_processing/raw_content_body/raw_article_1440770.txt
# Raw content body for article 1440759 saved to ./data_processing/raw_content_body/raw_article_1440759.txt
# Raw content body for article 1440795 saved to ./data_processing/raw_content_body/raw_article_1440795.txt

# %% [markdown]
# #### Extract out the "processed_table_content" as a .txt file to verify extraction

# %%
# Filter the DataFrame for rows where 'has_table' is True
filtered_df = df1[df1["has_table"]]

# Ensure the processed_table_content directory exists
processed_content_dir = "./data_processing/processed_table_content"
os.makedirs(processed_content_dir, exist_ok=True)

# Loop through each unique article ID in the filtered DataFrame
for article_id in filtered_df["id"].unique():
    # Filter the DataFrame for the specific article ID
    article_df = filtered_df[filtered_df["id"] == article_id]

    if not article_df.empty:
        # Extract the 'processed_table_content' column
        processed_content = article_df["processed_table_content"].astype(str).tolist()

        # Define the output file path
        output_txt_file = f"{processed_content_dir}/processed_table_content_{article_id}.txt"

        # Write the content to a text file
        with open(output_txt_file, "w") as file:
            for content in processed_content:
                file.write(content + "\n")  # Write each entry on a new line

        print(f"Processed table content for article {article_id} saved to {output_txt_file}")
# Out:
# Processed table content for article 1435040 saved to ./data_processing/processed_table_content/processed_table_content_1435040.txt
# Processed table content for article 1435071 saved to ./data_processing/processed_table_content/processed_table_content_1435071.txt
# Processed table content for article 1435043 saved to ./data_processing/processed_table_content/processed_table_content_1435043.txt
# Processed table content for article 1435005 saved to ./data_processing/processed_table_content/processed_table_content_1435005.txt
# Processed table content for article 1434994 saved to ./data_processing/processed_table_content/processed_table_content_1434994.txt
# Processed table content for article 1435059 saved to ./data_processing/processed_table_content/processed_table_content_1435059.txt
# Processed table content for article 1435029 saved to ./data_processing/processed_table_content/processed_table_content_1435029.txt
# Processed table content for article 1434998 saved to ./data_processing/processed_table_content/processed_table_content_1434998.txt
# Processed table content for article 1437795 saved to ./data_processing/processed_table_content/processed_table_content_1437795.txt
# Processed table content for article 1437742 saved to ./data_processing/processed_table_content/processed_table_content_1437742.txt
# Processed table content for article 1437786 saved to ./data_processing/processed_table_content/processed_table_content_1437786.txt
# Processed table content for article 1437477 saved to ./data_processing/processed_table_content/processed_table_content_1437477.txt
# Processed table content for article 1437357 saved to ./data_processing/processed_table_content/processed_table_content_1437357.txt
# Processed table content for article 1437751 saved to ./data_processing/processed_table_content/processed_table_content_1437751.txt
# Processed table content for article 1437629 saved to ./data_processing/processed_table_content/processed_table_content_1437629.txt
# Processed table content for article 1437583 saved to ./data_processing/processed_table_content/processed_table_content_1437583.txt
# Processed table content for article 1437890 saved to ./data_processing/processed_table_content/processed_table_content_1437890.txt
# Processed table content for article 1437423 saved to ./data_processing/processed_table_content/processed_table_content_1437423.txt
# Processed table content for article 1437794 saved to ./data_processing/processed_table_content/processed_table_content_1437794.txt
# Processed table content for article 1437587 saved to ./data_processing/processed_table_content/processed_table_content_1437587.txt
# Processed table content for article 1437331 saved to ./data_processing/processed_table_content/processed_table_content_1437331.txt
# Processed table content for article 1437338 saved to ./data_processing/processed_table_content/processed_table_content_1437338.txt
# Processed table content for article 1437888 saved to ./data_processing/processed_table_content/processed_table_content_1437888.txt
# Processed table content for article 1437593 saved to ./data_processing/processed_table_content/processed_table_content_1437593.txt
# Processed table content for article 1437766 saved to ./data_processing/processed_table_content/processed_table_content_1437766.txt
# Processed table content for article 1437353 saved to ./data_processing/processed_table_content/processed_table_content_1437353.txt
# Processed table content for article 1437712 saved to ./data_processing/processed_table_content/processed_table_content_1437712.txt
# Processed table content for article 1437856 saved to ./data_processing/processed_table_content/processed_table_content_1437856.txt
# Processed table content for article 1464135 saved to ./data_processing/processed_table_content/processed_table_content_1464135.txt
# Processed table content for article 1437760 saved to ./data_processing/processed_table_content/processed_table_content_1437760.txt
# Processed table content for article 1437960 saved to ./data_processing/processed_table_content/processed_table_content_1437960.txt
# Processed table content for article 1437954 saved to ./data_processing/processed_table_content/processed_table_content_1437954.txt
# Processed table content for article 1437958 saved to ./data_processing/processed_table_content/processed_table_content_1437958.txt
# Processed table content for article 1437942 saved to ./data_processing/processed_table_content/processed_table_content_1437942.txt
# Processed table content for article 1437956 saved to ./data_processing/processed_table_content/processed_table_content_1437956.txt
# Processed table content for article 1437940 saved to ./data_processing/processed_table_content/processed_table_content_1437940.txt
# Processed table content for article 1437962 saved to ./data_processing/processed_table_content/processed_table_content_1437962.txt
# Processed table content for article 1437964 saved to ./data_processing/processed_table_content/processed_table_content_1437964.txt
# Processed table content for article 1437938 saved to ./data_processing/processed_table_content/processed_table_content_1437938.txt
# Processed table content for article 1437946 saved to ./data_processing/processed_table_content/processed_table_content_1437946.txt
# Processed table content for article 1437950 saved to ./data_processing/processed_table_content/processed_table_content_1437950.txt
# Processed table content for article 1437966 saved to ./data_processing/processed_table_content/processed_table_content_1437966.txt
# Processed table content for article 1437952 saved to ./data_processing/processed_table_content/processed_table_content_1437952.txt
# Processed table content for article 1437948 saved to ./data_processing/processed_table_content/processed_table_content_1437948.txt
# Processed table content for article 1437944 saved to ./data_processing/processed_table_content/processed_table_content_1437944.txt
# Processed table content for article 1445137 saved to ./data_processing/processed_table_content/processed_table_content_1445137.txt
# Processed table content for article 1445282 saved to ./data_processing/processed_table_content/processed_table_content_1445282.txt
# Processed table content for article 1446016 saved to ./data_processing/processed_table_content/processed_table_content_1446016.txt
# Processed table content for article 1445852 saved to ./data_processing/processed_table_content/processed_table_content_1445852.txt
# Processed table content for article 1443987 saved to ./data_processing/processed_table_content/processed_table_content_1443987.txt
# Processed table content for article 1444820 saved to ./data_processing/processed_table_content/processed_table_content_1444820.txt
# Processed table content for article 1444912 saved to ./data_processing/processed_table_content/processed_table_content_1444912.txt
# Processed table content for article 1445136 saved to ./data_processing/processed_table_content/processed_table_content_1445136.txt
# Processed table content for article 1442923 saved to ./data_processing/processed_table_content/processed_table_content_1442923.txt
# Processed table content for article 1442691 saved to ./data_processing/processed_table_content/processed_table_content_1442691.txt
# Processed table content for article 1445148 saved to ./data_processing/processed_table_content/processed_table_content_1445148.txt
# Processed table content for article 1445479 saved to ./data_processing/processed_table_content/processed_table_content_1445479.txt
# Processed table content for article 1442502 saved to ./data_processing/processed_table_content/processed_table_content_1442502.txt
# Processed table content for article 1445643 saved to ./data_processing/processed_table_content/processed_table_content_1445643.txt
# Processed table content for article 1442421 saved to ./data_processing/processed_table_content/processed_table_content_1442421.txt
# Processed table content for article 1445277 saved to ./data_processing/processed_table_content/processed_table_content_1445277.txt
# Processed table content for article 1445178 saved to ./data_processing/processed_table_content/processed_table_content_1445178.txt
# Processed table content for article 1446031 saved to ./data_processing/processed_table_content/processed_table_content_1446031.txt
# Processed table content for article 1443701 saved to ./data_processing/processed_table_content/processed_table_content_1443701.txt
# Processed table content for article 1443584 saved to ./data_processing/processed_table_content/processed_table_content_1443584.txt
# Processed table content for article 1445042 saved to ./data_processing/processed_table_content/processed_table_content_1445042.txt
# Processed table content for article 1445959 saved to ./data_processing/processed_table_content/processed_table_content_1445959.txt
# Processed table content for article 1445505 saved to ./data_processing/processed_table_content/processed_table_content_1445505.txt
# Processed table content for article 1445162 saved to ./data_processing/processed_table_content/processed_table_content_1445162.txt
# Processed table content for article 1445484 saved to ./data_processing/processed_table_content/processed_table_content_1445484.txt
# Processed table content for article 1446066 saved to ./data_processing/processed_table_content/processed_table_content_1446066.txt
# Processed table content for article 1445167 saved to ./data_processing/processed_table_content/processed_table_content_1445167.txt
# Processed table content for article 1445447 saved to ./data_processing/processed_table_content/processed_table_content_1445447.txt
# Processed table content for article 1444056 saved to ./data_processing/processed_table_content/processed_table_content_1444056.txt
# Processed table content for article 1442782 saved to ./data_processing/processed_table_content/processed_table_content_1442782.txt
# Processed table content for article 1445144 saved to ./data_processing/processed_table_content/processed_table_content_1445144.txt
# Processed table content for article 1443088 saved to ./data_processing/processed_table_content/processed_table_content_1443088.txt
# Processed table content for article 1444565 saved to ./data_processing/processed_table_content/processed_table_content_1444565.txt
# Processed table content for article 1444852 saved to ./data_processing/processed_table_content/processed_table_content_1444852.txt
# Processed table content for article 1442686 saved to ./data_processing/processed_table_content/processed_table_content_1442686.txt
# Processed table content for article 1445143 saved to ./data_processing/processed_table_content/processed_table_content_1445143.txt
# Processed table content for article 1445899 saved to ./data_processing/processed_table_content/processed_table_content_1445899.txt
# Processed table content for article 1443475 saved to ./data_processing/processed_table_content/processed_table_content_1443475.txt
# Processed table content for article 1445147 saved to ./data_processing/processed_table_content/processed_table_content_1445147.txt
# Processed table content for article 1445689 saved to ./data_processing/processed_table_content/processed_table_content_1445689.txt
# Processed table content for article 1445859 saved to ./data_processing/processed_table_content/processed_table_content_1445859.txt
# Processed table content for article 1445172 saved to ./data_processing/processed_table_content/processed_table_content_1445172.txt
# Processed table content for article 1442681 saved to ./data_processing/processed_table_content/processed_table_content_1442681.txt
# Processed table content for article 1442755 saved to ./data_processing/processed_table_content/processed_table_content_1442755.txt
# Processed table content for article 1445117 saved to ./data_processing/processed_table_content/processed_table_content_1445117.txt
# Processed table content for article 1445603 saved to ./data_processing/processed_table_content/processed_table_content_1445603.txt
# Processed table content for article 1443082 saved to ./data_processing/processed_table_content/processed_table_content_1443082.txt
# Processed table content for article 1446045 saved to ./data_processing/processed_table_content/processed_table_content_1446045.txt
# Processed table content for article 1442571 saved to ./data_processing/processed_table_content/processed_table_content_1442571.txt
# Processed table content for article 1442456 saved to ./data_processing/processed_table_content/processed_table_content_1442456.txt
# Processed table content for article 1443393 saved to ./data_processing/processed_table_content/processed_table_content_1443393.txt
# Processed table content for article 1442664 saved to ./data_processing/processed_table_content/processed_table_content_1442664.txt
# Processed table content for article 1445568 saved to ./data_processing/processed_table_content/processed_table_content_1445568.txt
# Processed table content for article 1445862 saved to ./data_processing/processed_table_content/processed_table_content_1445862.txt
# Processed table content for article 1443323 saved to ./data_processing/processed_table_content/processed_table_content_1443323.txt
# Processed table content for article 1443020 saved to ./data_processing/processed_table_content/processed_table_content_1443020.txt
# Processed table content for article 1445386 saved to ./data_processing/processed_table_content/processed_table_content_1445386.txt
# Processed table content for article 1445854 saved to ./data_processing/processed_table_content/processed_table_content_1445854.txt
# Processed table content for article 1442545 saved to ./data_processing/processed_table_content/processed_table_content_1442545.txt
# Processed table content for article 1445777 saved to ./data_processing/processed_table_content/processed_table_content_1445777.txt
# Processed table content for article 1445774 saved to ./data_processing/processed_table_content/processed_table_content_1445774.txt
# Processed table content for article 1445669 saved to ./data_processing/processed_table_content/processed_table_content_1445669.txt
# Processed table content for article 1443351 saved to ./data_processing/processed_table_content/processed_table_content_1443351.txt
# Processed table content for article 1445456 saved to ./data_processing/processed_table_content/processed_table_content_1445456.txt
# Processed table content for article 1442509 saved to ./data_processing/processed_table_content/processed_table_content_1442509.txt
# Processed table content for article 1445738 saved to ./data_processing/processed_table_content/processed_table_content_1445738.txt
# Processed table content for article 1443094 saved to ./data_processing/processed_table_content/processed_table_content_1443094.txt
# Processed table content for article 1442785 saved to ./data_processing/processed_table_content/processed_table_content_1442785.txt
# Processed table content for article 1442929 saved to ./data_processing/processed_table_content/processed_table_content_1442929.txt
# Processed table content for article 1484558 saved to ./data_processing/processed_table_content/processed_table_content_1484558.txt
# Processed table content for article 1445911 saved to ./data_processing/processed_table_content/processed_table_content_1445911.txt
# Processed table content for article 1445517 saved to ./data_processing/processed_table_content/processed_table_content_1445517.txt
# Processed table content for article 1445898 saved to ./data_processing/processed_table_content/processed_table_content_1445898.txt
# Processed table content for article 1445330 saved to ./data_processing/processed_table_content/processed_table_content_1445330.txt
# Processed table content for article 1444615 saved to ./data_processing/processed_table_content/processed_table_content_1444615.txt
# Processed table content for article 1443392 saved to ./data_processing/processed_table_content/processed_table_content_1443392.txt
# Processed table content for article 1444566 saved to ./data_processing/processed_table_content/processed_table_content_1444566.txt
# Processed table content for article 1442550 saved to ./data_processing/processed_table_content/processed_table_content_1442550.txt
# Processed table content for article 1445620 saved to ./data_processing/processed_table_content/processed_table_content_1445620.txt
# Processed table content for article 1445937 saved to ./data_processing/processed_table_content/processed_table_content_1445937.txt
# Processed table content for article 1445668 saved to ./data_processing/processed_table_content/processed_table_content_1445668.txt
# Processed table content for article 1442667 saved to ./data_processing/processed_table_content/processed_table_content_1442667.txt
# Processed table content for article 1442464 saved to ./data_processing/processed_table_content/processed_table_content_1442464.txt
# Processed table content for article 1445850 saved to ./data_processing/processed_table_content/processed_table_content_1445850.txt
# Processed table content for article 1445538 saved to ./data_processing/processed_table_content/processed_table_content_1445538.txt
# Processed table content for article 1443557 saved to ./data_processing/processed_table_content/processed_table_content_1443557.txt
# Processed table content for article 1445213 saved to ./data_processing/processed_table_content/processed_table_content_1445213.txt
# Processed table content for article 1445088 saved to ./data_processing/processed_table_content/processed_table_content_1445088.txt
# Processed table content for article 1442928 saved to ./data_processing/processed_table_content/processed_table_content_1442928.txt
# Processed table content for article 1444303 saved to ./data_processing/processed_table_content/processed_table_content_1444303.txt
# Processed table content for article 1445711 saved to ./data_processing/processed_table_content/processed_table_content_1445711.txt
# Processed table content for article 1443054 saved to ./data_processing/processed_table_content/processed_table_content_1443054.txt
# Processed table content for article 1445582 saved to ./data_processing/processed_table_content/processed_table_content_1445582.txt
# Processed table content for article 1443389 saved to ./data_processing/processed_table_content/processed_table_content_1443389.txt
# Processed table content for article 1445724 saved to ./data_processing/processed_table_content/processed_table_content_1445724.txt
# Processed table content for article 1445622 saved to ./data_processing/processed_table_content/processed_table_content_1445622.txt
# Processed table content for article 1444065 saved to ./data_processing/processed_table_content/processed_table_content_1444065.txt
# Processed table content for article 1443042 saved to ./data_processing/processed_table_content/processed_table_content_1443042.txt
# Processed table content for article 1442765 saved to ./data_processing/processed_table_content/processed_table_content_1442765.txt
# Processed table content for article 1445346 saved to ./data_processing/processed_table_content/processed_table_content_1445346.txt
# Processed table content for article 1445917 saved to ./data_processing/processed_table_content/processed_table_content_1445917.txt
# Processed table content for article 1443310 saved to ./data_processing/processed_table_content/processed_table_content_1443310.txt
# Processed table content for article 1445311 saved to ./data_processing/processed_table_content/processed_table_content_1445311.txt
# Processed table content for article 1445204 saved to ./data_processing/processed_table_content/processed_table_content_1445204.txt
# Processed table content for article 1445681 saved to ./data_processing/processed_table_content/processed_table_content_1445681.txt
# Processed table content for article 1442510 saved to ./data_processing/processed_table_content/processed_table_content_1442510.txt
# Processed table content for article 1443043 saved to ./data_processing/processed_table_content/processed_table_content_1443043.txt
# Processed table content for article 1442654 saved to ./data_processing/processed_table_content/processed_table_content_1442654.txt
# Processed table content for article 1444658 saved to ./data_processing/processed_table_content/processed_table_content_1444658.txt
# Processed table content for article 1442339 saved to ./data_processing/processed_table_content/processed_table_content_1442339.txt
# Processed table content for article 1445616 saved to ./data_processing/processed_table_content/processed_table_content_1445616.txt
# Processed table content for article 1445956 saved to ./data_processing/processed_table_content/processed_table_content_1445956.txt
# Processed table content for article 1445618 saved to ./data_processing/processed_table_content/processed_table_content_1445618.txt
# Processed table content for article 1444879 saved to ./data_processing/processed_table_content/processed_table_content_1444879.txt
# Processed table content for article 1445613 saved to ./data_processing/processed_table_content/processed_table_content_1445613.txt
# Processed table content for article 1445607 saved to ./data_processing/processed_table_content/processed_table_content_1445607.txt
# Processed table content for article 1445611 saved to ./data_processing/processed_table_content/processed_table_content_1445611.txt
# Processed table content for article 1445485 saved to ./data_processing/processed_table_content/processed_table_content_1445485.txt
# Processed table content for article 1445707 saved to ./data_processing/processed_table_content/processed_table_content_1445707.txt
# Processed table content for article 1445599 saved to ./data_processing/processed_table_content/processed_table_content_1445599.txt
# Processed table content for article 1445291 saved to ./data_processing/processed_table_content/processed_table_content_1445291.txt
# Processed table content for article 1442577 saved to ./data_processing/processed_table_content/processed_table_content_1442577.txt
# Processed table content for article 1445605 saved to ./data_processing/processed_table_content/processed_table_content_1445605.txt
# Processed table content for article 1445608 saved to ./data_processing/processed_table_content/processed_table_content_1445608.txt
# Processed table content for article 1445460 saved to ./data_processing/processed_table_content/processed_table_content_1445460.txt
# Processed table content for article 1445673 saved to ./data_processing/processed_table_content/processed_table_content_1445673.txt
# Processed table content for article 1445601 saved to ./data_processing/processed_table_content/processed_table_content_1445601.txt
# Processed table content for article 1437992 saved to ./data_processing/processed_table_content/processed_table_content_1437992.txt
# Processed table content for article 1438002 saved to ./data_processing/processed_table_content/processed_table_content_1438002.txt
# Processed table content for article 1439046 saved to ./data_processing/processed_table_content/processed_table_content_1439046.txt
# Processed table content for article 1439058 saved to ./data_processing/processed_table_content/processed_table_content_1439058.txt
# Processed table content for article 1437995 saved to ./data_processing/processed_table_content/processed_table_content_1437995.txt
# Processed table content for article 1439066 saved to ./data_processing/processed_table_content/processed_table_content_1439066.txt
# Processed table content for article 1438730 saved to ./data_processing/processed_table_content/processed_table_content_1438730.txt
# Processed table content for article 1439070 saved to ./data_processing/processed_table_content/processed_table_content_1439070.txt
# Processed table content for article 1437970 saved to ./data_processing/processed_table_content/processed_table_content_1437970.txt
# Processed table content for article 1438375 saved to ./data_processing/processed_table_content/processed_table_content_1438375.txt
# Processed table content for article 1439074 saved to ./data_processing/processed_table_content/processed_table_content_1439074.txt
# Processed table content for article 1439989 saved to ./data_processing/processed_table_content/processed_table_content_1439989.txt
# Processed table content for article 1439448 saved to ./data_processing/processed_table_content/processed_table_content_1439448.txt
# Processed table content for article 1440653 saved to ./data_processing/processed_table_content/processed_table_content_1440653.txt
# Processed table content for article 1440492 saved to ./data_processing/processed_table_content/processed_table_content_1440492.txt
# Processed table content for article 1440166 saved to ./data_processing/processed_table_content/processed_table_content_1440166.txt
# Processed table content for article 1440254 saved to ./data_processing/processed_table_content/processed_table_content_1440254.txt
# Processed table content for article 1439835 saved to ./data_processing/processed_table_content/processed_table_content_1439835.txt
# Processed table content for article 1439849 saved to ./data_processing/processed_table_content/processed_table_content_1439849.txt
# Processed table content for article 1440233 saved to ./data_processing/processed_table_content/processed_table_content_1440233.txt
# Processed table content for article 1440230 saved to ./data_processing/processed_table_content/processed_table_content_1440230.txt
# Processed table content for article 1440238 saved to ./data_processing/processed_table_content/processed_table_content_1440238.txt
# Processed table content for article 1439800 saved to ./data_processing/processed_table_content/processed_table_content_1439800.txt
# Processed table content for article 1471925 saved to ./data_processing/processed_table_content/processed_table_content_1471925.txt
# Processed table content for article 1439589 saved to ./data_processing/processed_table_content/processed_table_content_1439589.txt
# Processed table content for article 1440258 saved to ./data_processing/processed_table_content/processed_table_content_1440258.txt
# Processed table content for article 1439975 saved to ./data_processing/processed_table_content/processed_table_content_1439975.txt
# Processed table content for article 1440453 saved to ./data_processing/processed_table_content/processed_table_content_1440453.txt
# Processed table content for article 1439798 saved to ./data_processing/processed_table_content/processed_table_content_1439798.txt
# Processed table content for article 1471768 saved to ./data_processing/processed_table_content/processed_table_content_1471768.txt
# Processed table content for article 1440237 saved to ./data_processing/processed_table_content/processed_table_content_1440237.txt
# Processed table content for article 1440457 saved to ./data_processing/processed_table_content/processed_table_content_1440457.txt
# Processed table content for article 1440408 saved to ./data_processing/processed_table_content/processed_table_content_1440408.txt
# Processed table content for article 1498738 saved to ./data_processing/processed_table_content/processed_table_content_1498738.txt
# Processed table content for article 1470581 saved to ./data_processing/processed_table_content/processed_table_content_1470581.txt
# Processed table content for article 1439839 saved to ./data_processing/processed_table_content/processed_table_content_1439839.txt
# Processed table content for article 1439777 saved to ./data_processing/processed_table_content/processed_table_content_1439777.txt
# Processed table content for article 1439952 saved to ./data_processing/processed_table_content/processed_table_content_1439952.txt
# Processed table content for article 1439226 saved to ./data_processing/processed_table_content/processed_table_content_1439226.txt
# Processed table content for article 1440434 saved to ./data_processing/processed_table_content/processed_table_content_1440434.txt
# Processed table content for article 1439887 saved to ./data_processing/processed_table_content/processed_table_content_1439887.txt
# Processed table content for article 1477242 saved to ./data_processing/processed_table_content/processed_table_content_1477242.txt
# Processed table content for article 1440474 saved to ./data_processing/processed_table_content/processed_table_content_1440474.txt
# Processed table content for article 1439803 saved to ./data_processing/processed_table_content/processed_table_content_1439803.txt
# Processed table content for article 1440432 saved to ./data_processing/processed_table_content/processed_table_content_1440432.txt
# Processed table content for article 1485623 saved to ./data_processing/processed_table_content/processed_table_content_1485623.txt
# Processed table content for article 1439758 saved to ./data_processing/processed_table_content/processed_table_content_1439758.txt
# Processed table content for article 1440406 saved to ./data_processing/processed_table_content/processed_table_content_1440406.txt
# Processed table content for article 1485631 saved to ./data_processing/processed_table_content/processed_table_content_1485631.txt
# Processed table content for article 1485693 saved to ./data_processing/processed_table_content/processed_table_content_1485693.txt
# Processed table content for article 1439769 saved to ./data_processing/processed_table_content/processed_table_content_1439769.txt
# Processed table content for article 1470789 saved to ./data_processing/processed_table_content/processed_table_content_1470789.txt
# Processed table content for article 1440262 saved to ./data_processing/processed_table_content/processed_table_content_1440262.txt
# Processed table content for article 1498740 saved to ./data_processing/processed_table_content/processed_table_content_1498740.txt
# Processed table content for article 1499904 saved to ./data_processing/processed_table_content/processed_table_content_1499904.txt
# Processed table content for article 1485685 saved to ./data_processing/processed_table_content/processed_table_content_1485685.txt
# Processed table content for article 1499902 saved to ./data_processing/processed_table_content/processed_table_content_1499902.txt
# Processed table content for article 1499906 saved to ./data_processing/processed_table_content/processed_table_content_1499906.txt
# Processed table content for article 1499891 saved to ./data_processing/processed_table_content/processed_table_content_1499891.txt
# Processed table content for article 1499898 saved to ./data_processing/processed_table_content/processed_table_content_1499898.txt
# Processed table content for article 1440511 saved to ./data_processing/processed_table_content/processed_table_content_1440511.txt
# Processed table content for article 1440529 saved to ./data_processing/processed_table_content/processed_table_content_1440529.txt
# Processed table content for article 1434612 saved to ./data_processing/processed_table_content/processed_table_content_1434612.txt
# Processed table content for article 1434580 saved to ./data_processing/processed_table_content/processed_table_content_1434580.txt
# Processed table content for article 1453207 saved to ./data_processing/processed_table_content/processed_table_content_1453207.txt
# Processed table content for article 1434596 saved to ./data_processing/processed_table_content/processed_table_content_1434596.txt
# Processed table content for article 1434716 saved to ./data_processing/processed_table_content/processed_table_content_1434716.txt
# Processed table content for article 1434574 saved to ./data_processing/processed_table_content/processed_table_content_1434574.txt
# Processed table content for article 1462073 saved to ./data_processing/processed_table_content/processed_table_content_1462073.txt
# Processed table content for article 1434624 saved to ./data_processing/processed_table_content/processed_table_content_1434624.txt
# Processed table content for article 1434604 saved to ./data_processing/processed_table_content/processed_table_content_1434604.txt
# Processed table content for article 1434670 saved to ./data_processing/processed_table_content/processed_table_content_1434670.txt
# Processed table content for article 1434570 saved to ./data_processing/processed_table_content/processed_table_content_1434570.txt
# Processed table content for article 1434602 saved to ./data_processing/processed_table_content/processed_table_content_1434602.txt
# Processed table content for article 1434608 saved to ./data_processing/processed_table_content/processed_table_content_1434608.txt
# Processed table content for article 1434626 saved to ./data_processing/processed_table_content/processed_table_content_1434626.txt
# Processed table content for article 1434622 saved to ./data_processing/processed_table_content/processed_table_content_1434622.txt
# Processed table content for article 1434630 saved to ./data_processing/processed_table_content/processed_table_content_1434630.txt
# Processed table content for article 1434594 saved to ./data_processing/processed_table_content/processed_table_content_1434594.txt
# Processed table content for article 1435221 saved to ./data_processing/processed_table_content/processed_table_content_1435221.txt
# Processed table content for article 1434809 saved to ./data_processing/processed_table_content/processed_table_content_1434809.txt
# Processed table content for article 1434811 saved to ./data_processing/processed_table_content/processed_table_content_1434811.txt
# Processed table content for article 1435231 saved to ./data_processing/processed_table_content/processed_table_content_1435231.txt
# Processed table content for article 1435240 saved to ./data_processing/processed_table_content/processed_table_content_1435240.txt
# Processed table content for article 1434892 saved to ./data_processing/processed_table_content/processed_table_content_1434892.txt
# Processed table content for article 1434857 saved to ./data_processing/processed_table_content/processed_table_content_1434857.txt
# Processed table content for article 1434803 saved to ./data_processing/processed_table_content/processed_table_content_1434803.txt
# Processed table content for article 1435083 saved to ./data_processing/processed_table_content/processed_table_content_1435083.txt
# Processed table content for article 1434899 saved to ./data_processing/processed_table_content/processed_table_content_1434899.txt
# Processed table content for article 1434823 saved to ./data_processing/processed_table_content/processed_table_content_1434823.txt
# Processed table content for article 1434821 saved to ./data_processing/processed_table_content/processed_table_content_1434821.txt
# Processed table content for article 1434867 saved to ./data_processing/processed_table_content/processed_table_content_1434867.txt
# Processed table content for article 1434865 saved to ./data_processing/processed_table_content/processed_table_content_1434865.txt
# Processed table content for article 1435313 saved to ./data_processing/processed_table_content/processed_table_content_1435313.txt
# Processed table content for article 1440770 saved to ./data_processing/processed_table_content/processed_table_content_1440770.txt
# Processed table content for article 1440759 saved to ./data_processing/processed_table_content/processed_table_content_1440759.txt
# Processed table content for article 1440795 saved to ./data_processing/processed_table_content/processed_table_content_1440795.txt

# %% [markdown]
# #### Check that processed_table_content is added as the last column of the new index

# %%
# Print all columns of the DataFrame
print("Columns in DataFrame:")
for column in df1.columns:
    print(column)
# Out:
# Columns in DataFrame:
# id
# content_name
# title
# article_category_names
# cover_image_url
# full_url
# full_url2
# friendly_url
# category_description
# content_body
# keywords
# feature_title
# pr_name
# alternate_image_text
# date_modified
# number_of_views
# last_month_view_count
# last_two_months_view
# content_category
# to_remove
# remove_type
# has_table
# has_image
# related_sections
# extracted_tables
# extracted_raw_html_tables
# extracted_links
# extracted_headers
# extracted_images
# extracted_content_body
# l1_mappings
# l2_mappings
# page_views
# engagement_rate
# bounce_rate
# exit_rate
# scroll_percentage
# percentage_total_views
# cumulative_percentage_total_views
# processed_table_content

# %% [markdown]
# #### Specify the columns to extract for article content and tables

# %%
# columns_to_extract1 are the columns for the article content
# columns_to_extract2 are the columns for the table content
columns_to_extract1 = [
    "id",
    "title",
    "cover_image_url",
    "full_url",
    "extracted_content_body",
    "content_category",
    "category_description",
    "pr_name",
    "date_modified",
    "has_table",  # Add this column to filter rows with tables after extracting the content
]

columns_to_extract2 = [
    "id",
    "title",
    "cover_image_url",
    "full_url",
    "processed_table_content",
    "content_category",
    "category_description",
    "pr_name",
    "date_modified",
]

# %% [markdown]
# #### Entire parquet extraction

# %%
# Specify the directory
output_directory = "./data_processing/processed_articles"

# Ensure the directory exists
os.makedirs(output_directory, exist_ok=True)

# Loop through each row in the DataFrame using iterrows()
for index, row in df1.iterrows():
    # Extract the id of the row
    row_id = row["id"]

    # Extract the specified columns for the given row
    extracted_row1 = row[columns_to_extract1]
    has_table = extracted_row1["has_table"]  # Check if the row has a table

    # Convert the extracted row to a dictionary and remove 'has_table'
    extracted_data1 = extracted_row1.drop("has_table").to_dict()

    # Rename the key to "content"
    extracted_data1["content"] = str(extracted_data1.pop("extracted_content_body"))

    # Convert the id field to string and append a suffix
    extracted_data1["id"] = str(row_id) + "_content"

    # Wrap the dictionary in a list to match the desired format
    extracted_data_list1 = [extracted_data1]

    # Create a unique filename using the row ID
    output_filename1 = f"{row_id}_content.json"  # For content body

    # Define the output path
    output_path1 = os.path.join(output_directory, output_filename1)

    # Export the extracted content body to a JSON file
    with open(output_path1, "w") as json_file:
        json.dump(extracted_data_list1, json_file, indent=4)

    # If there is a table, extract and save it as well
    if has_table:
        extracted_row2 = row[columns_to_extract2]
        extracted_data2 = extracted_row2.to_dict()
        extracted_data2["content"] = str(extracted_data2.pop("processed_table_content"))

        # Convert the id field to string and append a suffix
        extracted_data2["id"] = str(row_id) + "_table"

        # Wrap the dictionary in a list to match the desired format
        extracted_data_list2 = [extracted_data2]

        # Create a unique filename for the table content
        output_filename2 = f"{row_id}_table.json"  # For raw HTML tables
        output_path2 = os.path.join(output_directory, output_filename2)

        # Export the extracted raw HTML tables to a JSON file
        with open(output_path2, "w") as json_file:
            json.dump(extracted_data_list2, json_file, indent=4)

        # Confirm the files were saved
        print(f"JSON files saved at: {output_path1} and {output_path2}")
    else:
        # Confirm the content body file was saved
        print(f"JSON file saved at: {output_path1}")
# Out:
# JSON files saved at: ./data_processing/processed_articles/1435040_content.json and ./data_processing/processed_articles/1435040_table.json
# JSON files saved at: ./data_processing/processed_articles/1435071_content.json and ./data_processing/processed_articles/1435071_table.json
# JSON file saved at: ./data_processing/processed_articles/1434993_content.json
# JSON file saved at: ./data_processing/processed_articles/1435031_content.json
# JSON files saved at: ./data_processing/processed_articles/1435043_content.json and ./data_processing/processed_articles/1435043_table.json
# JSON files saved at: ./data_processing/processed_articles/1435005_content.json and ./data_processing/processed_articles/1435005_table.json
# JSON files saved at: ./data_processing/processed_articles/1434994_content.json and ./data_processing/processed_articles/1434994_table.json
# JSON file saved at: ./data_processing/processed_articles/1435035_content.json
# JSON file saved at: ./data_processing/processed_articles/1435064_content.json
# JSON file saved at: ./data_processing/processed_articles/1435063_content.json
# JSON files saved at: ./data_processing/processed_articles/1435059_content.json and ./data_processing/processed_articles/1435059_table.json
# JSON file saved at: ./data_processing/processed_articles/1435036_content.json
# JSON files saved at: ./data_processing/processed_articles/1435029_content.json and ./data_processing/processed_articles/1435029_table.json
# JSON file saved at: ./data_processing/processed_articles/1435057_content.json
# JSON file saved at: ./data_processing/processed_articles/1435009_content.json
# JSON file saved at: ./data_processing/processed_articles/1435032_content.json
# JSON file saved at: ./data_processing/processed_articles/1435010_content.json
# JSON file saved at: ./data_processing/processed_articles/1435044_content.json
# JSON file saved at: ./data_processing/processed_articles/1435051_content.json
# JSON file saved at: ./data_processing/processed_articles/1435002_content.json
# JSON file saved at: ./data_processing/processed_articles/1435006_content.json
# JSON file saved at: ./data_processing/processed_articles/1434997_content.json
# JSON file saved at: ./data_processing/processed_articles/1435001_content.json
# JSON files saved at: ./data_processing/processed_articles/1434998_content.json and ./data_processing/processed_articles/1434998_table.json
# JSON files saved at: ./data_processing/processed_articles/1437795_content.json and ./data_processing/processed_articles/1437795_table.json
# JSON files saved at: ./data_processing/processed_articles/1437742_content.json and ./data_processing/processed_articles/1437742_table.json
# JSON file saved at: ./data_processing/processed_articles/1437732_content.json
# JSON file saved at: ./data_processing/processed_articles/1437433_content.json
# JSON file saved at: ./data_processing/processed_articles/1437832_content.json
# JSON file saved at: ./data_processing/processed_articles/1437894_content.json
# JSON file saved at: ./data_processing/processed_articles/1437295_content.json
# JSON file saved at: ./data_processing/processed_articles/1437509_content.json
# JSON files saved at: ./data_processing/processed_articles/1437786_content.json and ./data_processing/processed_articles/1437786_table.json
# JSON file saved at: ./data_processing/processed_articles/1437337_content.json
# JSON file saved at: ./data_processing/processed_articles/1437380_content.json
# JSON files saved at: ./data_processing/processed_articles/1437477_content.json and ./data_processing/processed_articles/1437477_table.json
# JSON file saved at: ./data_processing/processed_articles/1437817_content.json
# JSON file saved at: ./data_processing/processed_articles/1437311_content.json
# JSON file saved at: ./data_processing/processed_articles/1437643_content.json
# JSON file saved at: ./data_processing/processed_articles/1437409_content.json
# JSON file saved at: ./data_processing/processed_articles/1437525_content.json
# JSON file saved at: ./data_processing/processed_articles/1437896_content.json
# JSON file saved at: ./data_processing/processed_articles/1437553_content.json
# JSON file saved at: ./data_processing/processed_articles/1437681_content.json
# JSON file saved at: ./data_processing/processed_articles/1437363_content.json
# JSON file saved at: ./data_processing/processed_articles/1437303_content.json
# JSON file saved at: ./data_processing/processed_articles/1437633_content.json
# JSON file saved at: ./data_processing/processed_articles/1437623_content.json
# JSON file saved at: ./data_processing/processed_articles/1437716_content.json
# JSON file saved at: ./data_processing/processed_articles/1437803_content.json
# JSON files saved at: ./data_processing/processed_articles/1437357_content.json and ./data_processing/processed_articles/1437357_table.json
# JSON file saved at: ./data_processing/processed_articles/1437342_content.json
# JSON files saved at: ./data_processing/processed_articles/1437751_content.json and ./data_processing/processed_articles/1437751_table.json
# JSON file saved at: ./data_processing/processed_articles/1437639_content.json
# JSON files saved at: ./data_processing/processed_articles/1437629_content.json and ./data_processing/processed_articles/1437629_table.json
# JSON file saved at: ./data_processing/processed_articles/1437625_content.json
# JSON file saved at: ./data_processing/processed_articles/1437615_content.json
# JSON file saved at: ./data_processing/processed_articles/1437329_content.json
# JSON file saved at: ./data_processing/processed_articles/1437313_content.json
# JSON file saved at: ./data_processing/processed_articles/1437491_content.json
# JSON file saved at: ./data_processing/processed_articles/1437828_content.json
# JSON file saved at: ./data_processing/processed_articles/1437734_content.json
# JSON file saved at: ./data_processing/processed_articles/1437645_content.json
# JSON file saved at: ./data_processing/processed_articles/1437391_content.json
# JSON file saved at: ./data_processing/processed_articles/1437405_content.json
# JSON file saved at: ./data_processing/processed_articles/1437573_content.json
# JSON file saved at: ./data_processing/processed_articles/1437469_content.json
# JSON file saved at: ./data_processing/processed_articles/1437694_content.json
# JSON file saved at: ./data_processing/processed_articles/1437425_content.json
# JSON file saved at: ./data_processing/processed_articles/1437728_content.json
# JSON file saved at: ./data_processing/processed_articles/1437661_content.json
# JSON file saved at: ./data_processing/processed_articles/1437613_content.json
# JSON file saved at: ./data_processing/processed_articles/1437388_content.json
# JSON file saved at: ./data_processing/processed_articles/1437868_content.json
# JSON file saved at: ./data_processing/processed_articles/1437495_content.json
# JSON file saved at: ./data_processing/processed_articles/1437437_content.json
# JSON file saved at: ./data_processing/processed_articles/1437619_content.json
# JSON files saved at: ./data_processing/processed_articles/1437583_content.json and ./data_processing/processed_articles/1437583_table.json
# JSON file saved at: ./data_processing/processed_articles/1437880_content.json
# JSON file saved at: ./data_processing/processed_articles/1437647_content.json
# JSON file saved at: ./data_processing/processed_articles/1437864_content.json
# JSON file saved at: ./data_processing/processed_articles/1437659_content.json
# JSON file saved at: ./data_processing/processed_articles/1437631_content.json
# JSON file saved at: ./data_processing/processed_articles/1437653_content.json
# JSON file saved at: ./data_processing/processed_articles/1437457_content.json
# JSON file saved at: ./data_processing/processed_articles/1437580_content.json
# JSON file saved at: ./data_processing/processed_articles/1437465_content.json
# JSON file saved at: ./data_processing/processed_articles/1437836_content.json
# JSON file saved at: ./data_processing/processed_articles/1437304_content.json
# JSON file saved at: ./data_processing/processed_articles/1437750_content.json
# JSON file saved at: ./data_processing/processed_articles/1437738_content.json
# JSON file saved at: ./data_processing/processed_articles/1437325_content.json
# JSON files saved at: ./data_processing/processed_articles/1437890_content.json and ./data_processing/processed_articles/1437890_table.json
# JSON file saved at: ./data_processing/processed_articles/1437402_content.json
# JSON file saved at: ./data_processing/processed_articles/1437678_content.json
# JSON file saved at: ./data_processing/processed_articles/1437345_content.json
# JSON file saved at: ./data_processing/processed_articles/1437735_content.json
# JSON file saved at: ./data_processing/processed_articles/1437669_content.json
# JSON file saved at: ./data_processing/processed_articles/1437884_content.json
# JSON file saved at: ./data_processing/processed_articles/1437876_content.json
# JSON file saved at: ./data_processing/processed_articles/1437401_content.json
# JSON file saved at: ./data_processing/processed_articles/1437458_content.json
# JSON file saved at: ./data_processing/processed_articles/1437872_content.json
# JSON file saved at: ./data_processing/processed_articles/1437399_content.json
# JSON file saved at: ./data_processing/processed_articles/1437301_content.json
# JSON file saved at: ./data_processing/processed_articles/1437820_content.json
# JSON file saved at: ./data_processing/processed_articles/1437538_content.json
# JSON file saved at: ./data_processing/processed_articles/1437510_content.json
# JSON file saved at: ./data_processing/processed_articles/1437513_content.json
# JSON file saved at: ./data_processing/processed_articles/1437810_content.json
# JSON file saved at: ./data_processing/processed_articles/1437429_content.json
# JSON file saved at: ./data_processing/processed_articles/1437561_content.json
# JSON file saved at: ./data_processing/processed_articles/1437455_content.json
# JSON file saved at: ./data_processing/processed_articles/1437829_content.json
# JSON file saved at: ./data_processing/processed_articles/1437778_content.json
# JSON file saved at: ./data_processing/processed_articles/1437315_content.json
# JSON file saved at: ./data_processing/processed_articles/1437874_content.json
# JSON file saved at: ./data_processing/processed_articles/1437355_content.json
# JSON files saved at: ./data_processing/processed_articles/1437423_content.json and ./data_processing/processed_articles/1437423_table.json
# JSON file saved at: ./data_processing/processed_articles/1490357_content.json
# JSON file saved at: ./data_processing/processed_articles/1437730_content.json
# JSON file saved at: ./data_processing/processed_articles/1437518_content.json
# JSON file saved at: ./data_processing/processed_articles/1437417_content.json
# JSON file saved at: ./data_processing/processed_articles/1437627_content.json
# JSON file saved at: ./data_processing/processed_articles/1437802_content.json
# JSON file saved at: ./data_processing/processed_articles/1437816_content.json
# JSON file saved at: ./data_processing/processed_articles/1437555_content.json
# JSON file saved at: ./data_processing/processed_articles/1437635_content.json
# JSON file saved at: ./data_processing/processed_articles/1437443_content.json
# JSON file saved at: ./data_processing/processed_articles/1437397_content.json
# JSON files saved at: ./data_processing/processed_articles/1437794_content.json and ./data_processing/processed_articles/1437794_table.json
# JSON file saved at: ./data_processing/processed_articles/1437426_content.json
# JSON file saved at: ./data_processing/processed_articles/1437502_content.json
# JSON files saved at: ./data_processing/processed_articles/1437587_content.json and ./data_processing/processed_articles/1437587_table.json
# JSON file saved at: ./data_processing/processed_articles/1437529_content.json
# JSON file saved at: ./data_processing/processed_articles/1437385_content.json
# JSON file saved at: ./data_processing/processed_articles/1437860_content.json
# JSON file saved at: ./data_processing/processed_articles/1437641_content.json
# JSON file saved at: ./data_processing/processed_articles/1437471_content.json
# JSON file saved at: ./data_processing/processed_articles/1437507_content.json
# JSON file saved at: ./data_processing/processed_articles/1437611_content.json
# JSON file saved at: ./data_processing/processed_articles/1437784_content.json
# JSON file saved at: ./data_processing/processed_articles/1437740_content.json
# JSON file saved at: ./data_processing/processed_articles/1437848_content.json
# JSON file saved at: ./data_processing/processed_articles/1437663_content.json
# JSON file saved at: ./data_processing/processed_articles/1437485_content.json
# JSON file saved at: ./data_processing/processed_articles/1437579_content.json
# JSON file saved at: ./data_processing/processed_articles/1437406_content.json
# JSON file saved at: ./data_processing/processed_articles/1437346_content.json
# JSON file saved at: ./data_processing/processed_articles/1437591_content.json
# JSON file saved at: ./data_processing/processed_articles/1437430_content.json
# JSON file saved at: ./data_processing/processed_articles/1437533_content.json
# JSON file saved at: ./data_processing/processed_articles/1437497_content.json
# JSON file saved at: ./data_processing/processed_articles/1437850_content.json
# JSON file saved at: ./data_processing/processed_articles/1437461_content.json
# JSON file saved at: ./data_processing/processed_articles/1437293_content.json
# JSON files saved at: ./data_processing/processed_articles/1437331_content.json and ./data_processing/processed_articles/1437331_table.json
# JSON file saved at: ./data_processing/processed_articles/1437359_content.json
# JSON file saved at: ./data_processing/processed_articles/1437449_content.json
# JSON file saved at: ./data_processing/processed_articles/1437498_content.json
# JSON file saved at: ./data_processing/processed_articles/1437462_content.json
# JSON file saved at: ./data_processing/processed_articles/1437603_content.json
# JSON file saved at: ./data_processing/processed_articles/1437493_content.json
# JSON file saved at: ./data_processing/processed_articles/1437892_content.json
# JSON file saved at: ./data_processing/processed_articles/1437719_content.json
# JSON file saved at: ./data_processing/processed_articles/1437571_content.json
# JSON files saved at: ./data_processing/processed_articles/1437338_content.json and ./data_processing/processed_articles/1437338_table.json
# JSON file saved at: ./data_processing/processed_articles/1437549_content.json
# JSON file saved at: ./data_processing/processed_articles/1437609_content.json
# JSON file saved at: ./data_processing/processed_articles/1437521_content.json
# JSON file saved at: ./data_processing/processed_articles/1437319_content.json
# JSON file saved at: ./data_processing/processed_articles/1437648_content.json
# JSON file saved at: ./data_processing/processed_articles/1437616_content.json
# JSON file saved at: ./data_processing/processed_articles/1437651_content.json
# JSON file saved at: ./data_processing/processed_articles/1437877_content.json
# JSON file saved at: ./data_processing/processed_articles/1437898_content.json
# JSON file saved at: ./data_processing/processed_articles/1437800_content.json
# JSON file saved at: ./data_processing/processed_articles/1437814_content.json
# JSON file saved at: ./data_processing/processed_articles/1437341_content.json
# JSON file saved at: ./data_processing/processed_articles/1437667_content.json
# JSON file saved at: ./data_processing/processed_articles/1437576_content.json
# JSON file saved at: ./data_processing/processed_articles/1437620_content.json
# JSON file saved at: ./data_processing/processed_articles/1490824_content.json
# JSON file saved at: ./data_processing/processed_articles/1437411_content.json
# JSON file saved at: ./data_processing/processed_articles/1437722_content.json
# JSON file saved at: ./data_processing/processed_articles/1437834_content.json
# JSON files saved at: ./data_processing/processed_articles/1437888_content.json and ./data_processing/processed_articles/1437888_table.json
# JSON file saved at: ./data_processing/processed_articles/1437657_content.json
# JSON file saved at: ./data_processing/processed_articles/1437321_content.json
# JSON file saved at: ./data_processing/processed_articles/1437501_content.json
# JSON file saved at: ./data_processing/processed_articles/1437466_content.json
# JSON file saved at: ./data_processing/processed_articles/1437308_content.json
# JSON file saved at: ./data_processing/processed_articles/1437882_content.json
# JSON file saved at: ./data_processing/processed_articles/1437365_content.json
# JSON file saved at: ./data_processing/processed_articles/1437368_content.json
# JSON file saved at: ./data_processing/processed_articles/1437854_content.json
# JSON file saved at: ./data_processing/processed_articles/1437563_content.json
# JSON file saved at: ./data_processing/processed_articles/1437718_content.json
# JSON file saved at: ./data_processing/processed_articles/1437478_content.json
# JSON file saved at: ./data_processing/processed_articles/1437367_content.json
# JSON files saved at: ./data_processing/processed_articles/1437593_content.json and ./data_processing/processed_articles/1437593_table.json
# JSON file saved at: ./data_processing/processed_articles/1437349_content.json
# JSON file saved at: ./data_processing/processed_articles/1437514_content.json
# JSON file saved at: ./data_processing/processed_articles/1437673_content.json
# JSON file saved at: ./data_processing/processed_articles/1437527_content.json
# JSON file saved at: ./data_processing/processed_articles/1437824_content.json
# JSON file saved at: ./data_processing/processed_articles/1437685_content.json
# JSON file saved at: ./data_processing/processed_articles/1437373_content.json
# JSON file saved at: ./data_processing/processed_articles/1437387_content.json
# JSON file saved at: ./data_processing/processed_articles/1437473_content.json
# JSON file saved at: ./data_processing/processed_articles/1437756_content.json
# JSON file saved at: ./data_processing/processed_articles/1437375_content.json
# JSON files saved at: ./data_processing/processed_articles/1437766_content.json and ./data_processing/processed_articles/1437766_table.json
# JSON file saved at: ./data_processing/processed_articles/1437475_content.json
# JSON file saved at: ./data_processing/processed_articles/1437683_content.json
# JSON file saved at: ./data_processing/processed_articles/1437557_content.json
# JSON file saved at: ./data_processing/processed_articles/1437798_content.json
# JSON file saved at: ./data_processing/processed_articles/1437323_content.json
# JSON file saved at: ./data_processing/processed_articles/1437866_content.json
# JSON file saved at: ./data_processing/processed_articles/1437505_content.json
# JSON file saved at: ./data_processing/processed_articles/1437541_content.json
# JSON file saved at: ./data_processing/processed_articles/1437655_content.json
# JSON file saved at: ./data_processing/processed_articles/1437421_content.json
# JSON file saved at: ./data_processing/processed_articles/1490905_content.json
# JSON file saved at: ./data_processing/processed_articles/1437445_content.json
# JSON file saved at: ./data_processing/processed_articles/1437605_content.json
# JSON file saved at: ./data_processing/processed_articles/1437714_content.json
# JSON file saved at: ./data_processing/processed_articles/1437545_content.json
# JSON file saved at: ./data_processing/processed_articles/1490477_content.json
# JSON file saved at: ./data_processing/processed_articles/1437724_content.json
# JSON file saved at: ./data_processing/processed_articles/1437743_content.json
# JSON file saved at: ./data_processing/processed_articles/1437844_content.json
# JSON file saved at: ./data_processing/processed_articles/1437772_content.json
# JSON file saved at: ./data_processing/processed_articles/1437565_content.json
# JSON file saved at: ./data_processing/processed_articles/1437842_content.json
# JSON files saved at: ./data_processing/processed_articles/1437353_content.json and ./data_processing/processed_articles/1437353_table.json
# JSON file saved at: ./data_processing/processed_articles/1437846_content.json
# JSON file saved at: ./data_processing/processed_articles/1437531_content.json
# JSON file saved at: ./data_processing/processed_articles/1437327_content.json
# JSON file saved at: ./data_processing/processed_articles/1437542_content.json
# JSON file saved at: ./data_processing/processed_articles/1437806_content.json
# JSON file saved at: ./data_processing/processed_articles/1437350_content.json
# JSON file saved at: ./data_processing/processed_articles/1437551_content.json
# JSON file saved at: ./data_processing/processed_articles/1437383_content.json
# JSON files saved at: ./data_processing/processed_articles/1437712_content.json and ./data_processing/processed_articles/1437712_table.json
# JSON file saved at: ./data_processing/processed_articles/1437746_content.json
# JSON file saved at: ./data_processing/processed_articles/1437747_content.json
# JSON file saved at: ./data_processing/processed_articles/1437547_content.json
# JSON file saved at: ./data_processing/processed_articles/1437481_content.json
# JSON file saved at: ./data_processing/processed_articles/1437376_content.json
# JSON file saved at: ./data_processing/processed_articles/1437489_content.json
# JSON file saved at: ./data_processing/processed_articles/1437594_content.json
# JSON file saved at: ./data_processing/processed_articles/1437439_content.json
# JSON file saved at: ./data_processing/processed_articles/1437585_content.json
# JSON file saved at: ./data_processing/processed_articles/1437782_content.json
# JSON file saved at: ./data_processing/processed_articles/1437774_content.json
# JSON file saved at: ./data_processing/processed_articles/1437559_content.json
# JSON file saved at: ./data_processing/processed_articles/1437447_content.json
# JSON file saved at: ./data_processing/processed_articles/1490464_content.json
# JSON file saved at: ./data_processing/processed_articles/1437607_content.json
# JSON file saved at: ./data_processing/processed_articles/1437371_content.json
# JSON file saved at: ./data_processing/processed_articles/1437453_content.json
# JSON file saved at: ./data_processing/processed_articles/1437395_content.json
# JSON file saved at: ./data_processing/processed_articles/1437599_content.json
# JSON file saved at: ./data_processing/processed_articles/1437419_content.json
# JSON file saved at: ./data_processing/processed_articles/1437537_content.json
# JSON file saved at: ./data_processing/processed_articles/1437486_content.json
# JSON file saved at: ./data_processing/processed_articles/1437811_content.json
# JSON file saved at: ./data_processing/processed_articles/1437840_content.json
# JSON file saved at: ./data_processing/processed_articles/1495896_content.json
# JSON file saved at: ./data_processing/processed_articles/1437870_content.json
# JSON file saved at: ./data_processing/processed_articles/1437601_content.json
# JSON file saved at: ./data_processing/processed_articles/1437826_content.json
# JSON file saved at: ./data_processing/processed_articles/1437360_content.json
# JSON file saved at: ./data_processing/processed_articles/1437588_content.json
# JSON file saved at: ./data_processing/processed_articles/1437665_content.json
# JSON file saved at: ./data_processing/processed_articles/1437568_content.json
# JSON file saved at: ./data_processing/processed_articles/1437710_content.json
# JSON file saved at: ./data_processing/processed_articles/1437451_content.json
# JSON file saved at: ./data_processing/processed_articles/1437852_content.json
# JSON file saved at: ./data_processing/processed_articles/1437317_content.json
# JSON file saved at: ./data_processing/processed_articles/1437379_content.json
# JSON file saved at: ./data_processing/processed_articles/1464915_content.json
# JSON file saved at: ./data_processing/processed_articles/1437790_content.json
# JSON file saved at: ./data_processing/processed_articles/1437671_content.json
# JSON file saved at: ./data_processing/processed_articles/1437858_content.json
# JSON file saved at: ./data_processing/processed_articles/1437567_content.json
# JSON file saved at: ./data_processing/processed_articles/1437838_content.json
# JSON file saved at: ./data_processing/processed_articles/1437637_content.json
# JSON file saved at: ./data_processing/processed_articles/1437415_content.json
# JSON file saved at: ./data_processing/processed_articles/1437575_content.json
# JSON file saved at: ./data_processing/processed_articles/1437764_content.json
# JSON file saved at: ./data_processing/processed_articles/1437770_content.json
# JSON file saved at: ./data_processing/processed_articles/1465254_content.json
# JSON file saved at: ./data_processing/processed_articles/1437297_content.json
# JSON file saved at: ./data_processing/processed_articles/1437862_content.json
# JSON file saved at: ./data_processing/processed_articles/1437807_content.json
# JSON file saved at: ./data_processing/processed_articles/1437413_content.json
# JSON file saved at: ./data_processing/processed_articles/1437687_content.json
# JSON file saved at: ./data_processing/processed_articles/1437821_content.json
# JSON file saved at: ./data_processing/processed_articles/1495894_content.json
# JSON file saved at: ./data_processing/processed_articles/1437522_content.json
# JSON file saved at: ./data_processing/processed_articles/1437768_content.json
# JSON file saved at: ./data_processing/processed_articles/1437677_content.json
# JSON files saved at: ./data_processing/processed_articles/1437856_content.json and ./data_processing/processed_articles/1437856_table.json
# JSON file saved at: ./data_processing/processed_articles/1437335_content.json
# JSON file saved at: ./data_processing/processed_articles/1437534_content.json
# JSON file saved at: ./data_processing/processed_articles/1437597_content.json
# JSON file saved at: ./data_processing/processed_articles/1437776_content.json
# JSON file saved at: ./data_processing/processed_articles/1437435_content.json
# JSON file saved at: ./data_processing/processed_articles/1437792_content.json
# JSON file saved at: ./data_processing/processed_articles/1437482_content.json
# JSON files saved at: ./data_processing/processed_articles/1464135_content.json and ./data_processing/processed_articles/1464135_table.json
# JSON file saved at: ./data_processing/processed_articles/1437517_content.json
# JSON file saved at: ./data_processing/processed_articles/1437393_content.json
# JSON file saved at: ./data_processing/processed_articles/1437333_content.json
# JSON file saved at: ./data_processing/processed_articles/1495902_content.json
# JSON file saved at: ./data_processing/processed_articles/1495898_content.json
# JSON file saved at: ./data_processing/processed_articles/1437726_content.json
# JSON file saved at: ./data_processing/processed_articles/1495900_content.json
# JSON file saved at: ./data_processing/processed_articles/1498736_content.json
# JSON file saved at: ./data_processing/processed_articles/1437780_content.json
# JSON file saved at: ./data_processing/processed_articles/1437441_content.json
# JSON file saved at: ./data_processing/processed_articles/1497537_content.json
# JSON file saved at: ./data_processing/processed_articles/1497541_content.json
# JSON file saved at: ./data_processing/processed_articles/1437788_content.json
# JSON file saved at: ./data_processing/processed_articles/1503125_content.json
# JSON file saved at: ./data_processing/processed_articles/1503136_content.json
# JSON file saved at: ./data_processing/processed_articles/1503129_content.json
# JSON file saved at: ./data_processing/processed_articles/1468231_content.json
# JSON file saved at: ./data_processing/processed_articles/1503133_content.json
# JSON file saved at: ./data_processing/processed_articles/1503131_content.json
# JSON file saved at: ./data_processing/processed_articles/1437754_content.json
# JSON files saved at: ./data_processing/processed_articles/1437760_content.json and ./data_processing/processed_articles/1437760_table.json
# JSON file saved at: ./data_processing/processed_articles/1503119_content.json
# JSON file saved at: ./data_processing/processed_articles/1503123_content.json
# JSON file saved at: ./data_processing/processed_articles/1503127_content.json
# JSON file saved at: ./data_processing/processed_articles/1437762_content.json
# JSON file saved at: ./data_processing/processed_articles/1437758_content.json
# JSON file saved at: ./data_processing/processed_articles/1437886_content.json
# JSON file saved at: ./data_processing/processed_articles/1503121_content.json
# JSON file saved at: ./data_processing/processed_articles/1497539_content.json
# JSON files saved at: ./data_processing/processed_articles/1437960_content.json and ./data_processing/processed_articles/1437960_table.json
# JSON files saved at: ./data_processing/processed_articles/1437954_content.json and ./data_processing/processed_articles/1437954_table.json
# JSON files saved at: ./data_processing/processed_articles/1437958_content.json and ./data_processing/processed_articles/1437958_table.json
# JSON files saved at: ./data_processing/processed_articles/1437942_content.json and ./data_processing/processed_articles/1437942_table.json
# JSON files saved at: ./data_processing/processed_articles/1437956_content.json and ./data_processing/processed_articles/1437956_table.json
# JSON files saved at: ./data_processing/processed_articles/1437940_content.json and ./data_processing/processed_articles/1437940_table.json
# JSON files saved at: ./data_processing/processed_articles/1437962_content.json and ./data_processing/processed_articles/1437962_table.json
# JSON files saved at: ./data_processing/processed_articles/1437964_content.json and ./data_processing/processed_articles/1437964_table.json
# JSON files saved at: ./data_processing/processed_articles/1437938_content.json and ./data_processing/processed_articles/1437938_table.json
# JSON files saved at: ./data_processing/processed_articles/1437946_content.json and ./data_processing/processed_articles/1437946_table.json
# JSON files saved at: ./data_processing/processed_articles/1437950_content.json and ./data_processing/processed_articles/1437950_table.json
# JSON files saved at: ./data_processing/processed_articles/1437966_content.json and ./data_processing/processed_articles/1437966_table.json
# JSON files saved at: ./data_processing/processed_articles/1437952_content.json and ./data_processing/processed_articles/1437952_table.json
# JSON files saved at: ./data_processing/processed_articles/1437948_content.json and ./data_processing/processed_articles/1437948_table.json
# JSON files saved at: ./data_processing/processed_articles/1437944_content.json and ./data_processing/processed_articles/1437944_table.json
# JSON file saved at: ./data_processing/processed_articles/1444475_content.json
# JSON files saved at: ./data_processing/processed_articles/1445137_content.json and ./data_processing/processed_articles/1445137_table.json
# JSON files saved at: ./data_processing/processed_articles/1445282_content.json and ./data_processing/processed_articles/1445282_table.json
# JSON file saved at: ./data_processing/processed_articles/1445982_content.json
# JSON file saved at: ./data_processing/processed_articles/1443111_content.json
# JSON files saved at: ./data_processing/processed_articles/1446016_content.json and ./data_processing/processed_articles/1446016_table.json
# JSON files saved at: ./data_processing/processed_articles/1445852_content.json and ./data_processing/processed_articles/1445852_table.json
# JSON files saved at: ./data_processing/processed_articles/1443987_content.json and ./data_processing/processed_articles/1443987_table.json
# JSON file saved at: ./data_processing/processed_articles/1444951_content.json
# JSON file saved at: ./data_processing/processed_articles/1442668_content.json
# JSON file saved at: ./data_processing/processed_articles/1446007_content.json
# JSON files saved at: ./data_processing/processed_articles/1444820_content.json and ./data_processing/processed_articles/1444820_table.json
# JSON file saved at: ./data_processing/processed_articles/1445263_content.json
# JSON files saved at: ./data_processing/processed_articles/1444912_content.json and ./data_processing/processed_articles/1444912_table.json
# JSON file saved at: ./data_processing/processed_articles/1444919_content.json
# JSON file saved at: ./data_processing/processed_articles/1446006_content.json
# JSON file saved at: ./data_processing/processed_articles/1442828_content.json
# JSON file saved at: ./data_processing/processed_articles/1446068_content.json
# JSON files saved at: ./data_processing/processed_articles/1445136_content.json and ./data_processing/processed_articles/1445136_table.json
# JSON file saved at: ./data_processing/processed_articles/1443568_content.json
# JSON files saved at: ./data_processing/processed_articles/1442923_content.json and ./data_processing/processed_articles/1442923_table.json
# JSON files saved at: ./data_processing/processed_articles/1442691_content.json and ./data_processing/processed_articles/1442691_table.json
# JSON file saved at: ./data_processing/processed_articles/1442335_content.json
# JSON file saved at: ./data_processing/processed_articles/1446027_content.json
# JSON file saved at: ./data_processing/processed_articles/1444886_content.json
# JSON files saved at: ./data_processing/processed_articles/1445148_content.json and ./data_processing/processed_articles/1445148_table.json
# JSON file saved at: ./data_processing/processed_articles/1443089_content.json
# JSON file saved at: ./data_processing/processed_articles/1444898_content.json
# JSON file saved at: ./data_processing/processed_articles/1442801_content.json
# JSON files saved at: ./data_processing/processed_articles/1445479_content.json and ./data_processing/processed_articles/1445479_table.json
# JSON file saved at: ./data_processing/processed_articles/1442600_content.json
# JSON files saved at: ./data_processing/processed_articles/1442502_content.json and ./data_processing/processed_articles/1442502_table.json
# JSON file saved at: ./data_processing/processed_articles/1445336_content.json
# JSON file saved at: ./data_processing/processed_articles/1442805_content.json
# JSON file saved at: ./data_processing/processed_articles/1445251_content.json
# JSON file saved at: ./data_processing/processed_articles/1445324_content.json
# JSON files saved at: ./data_processing/processed_articles/1445643_content.json and ./data_processing/processed_articles/1445643_table.json
# JSON files saved at: ./data_processing/processed_articles/1442421_content.json and ./data_processing/processed_articles/1442421_table.json
# JSON files saved at: ./data_processing/processed_articles/1445277_content.json and ./data_processing/processed_articles/1445277_table.json
# JSON files saved at: ./data_processing/processed_articles/1445178_content.json and ./data_processing/processed_articles/1445178_table.json
# JSON file saved at: ./data_processing/processed_articles/1443672_content.json
# JSON file saved at: ./data_processing/processed_articles/1446061_content.json
# JSON files saved at: ./data_processing/processed_articles/1446031_content.json and ./data_processing/processed_articles/1446031_table.json
# JSON file saved at: ./data_processing/processed_articles/1445310_content.json
# JSON file saved at: ./data_processing/processed_articles/1442375_content.json
# JSON files saved at: ./data_processing/processed_articles/1443701_content.json and ./data_processing/processed_articles/1443701_table.json
# JSON file saved at: ./data_processing/processed_articles/1444662_content.json
# JSON file saved at: ./data_processing/processed_articles/1442454_content.json
# JSON file saved at: ./data_processing/processed_articles/1443490_content.json
# JSON file saved at: ./data_processing/processed_articles/1443083_content.json
# JSON file saved at: ./data_processing/processed_articles/1444946_content.json
# JSON files saved at: ./data_processing/processed_articles/1443584_content.json and ./data_processing/processed_articles/1443584_table.json
# JSON file saved at: ./data_processing/processed_articles/1445421_content.json
# JSON file saved at: ./data_processing/processed_articles/1445372_content.json
# JSON file saved at: ./data_processing/processed_articles/1443887_content.json
# JSON files saved at: ./data_processing/processed_articles/1445042_content.json and ./data_processing/processed_articles/1445042_table.json
# JSON files saved at: ./data_processing/processed_articles/1445959_content.json and ./data_processing/processed_articles/1445959_table.json
# JSON file saved at: ./data_processing/processed_articles/1444841_content.json
# JSON file saved at: ./data_processing/processed_articles/1443481_content.json
# JSON file saved at: ./data_processing/processed_articles/1446086_content.json
# JSON file saved at: ./data_processing/processed_articles/1442389_content.json
# JSON file saved at: ./data_processing/processed_articles/1445682_content.json
# JSON file saved at: ./data_processing/processed_articles/1446042_content.json
# JSON file saved at: ./data_processing/processed_articles/1442350_content.json
# JSON file saved at: ./data_processing/processed_articles/1442360_content.json
# JSON file saved at: ./data_processing/processed_articles/1445594_content.json
# JSON file saved at: ./data_processing/processed_articles/1444263_content.json
# JSON file saved at: ./data_processing/processed_articles/1444135_content.json
# JSON file saved at: ./data_processing/processed_articles/1445564_content.json
# JSON file saved at: ./data_processing/processed_articles/1442419_content.json
# JSON files saved at: ./data_processing/processed_articles/1445505_content.json and ./data_processing/processed_articles/1445505_table.json
# JSON file saved at: ./data_processing/processed_articles/1442479_content.json
# JSON file saved at: ./data_processing/processed_articles/1443217_content.json
# JSON file saved at: ./data_processing/processed_articles/1442382_content.json
# JSON file saved at: ./data_processing/processed_articles/1442515_content.json
# JSON file saved at: ./data_processing/processed_articles/1445846_content.json
# JSON file saved at: ./data_processing/processed_articles/1443673_content.json
# JSON files saved at: ./data_processing/processed_articles/1445162_content.json and ./data_processing/processed_articles/1445162_table.json
# JSON file saved at: ./data_processing/processed_articles/1443524_content.json
# JSON file saved at: ./data_processing/processed_articles/1445553_content.json
# JSON file saved at: ./data_processing/processed_articles/1443731_content.json
# JSON file saved at: ./data_processing/processed_articles/1445996_content.json
# JSON files saved at: ./data_processing/processed_articles/1445484_content.json and ./data_processing/processed_articles/1445484_table.json
# JSON file saved at: ./data_processing/processed_articles/1443695_content.json
# JSON file saved at: ./data_processing/processed_articles/1442498_content.json
# JSON files saved at: ./data_processing/processed_articles/1446066_content.json and ./data_processing/processed_articles/1446066_table.json
# JSON file saved at: ./data_processing/processed_articles/1444064_content.json
# JSON file saved at: ./data_processing/processed_articles/1445074_content.json
# JSON files saved at: ./data_processing/processed_articles/1445167_content.json and ./data_processing/processed_articles/1445167_table.json
# JSON file saved at: ./data_processing/processed_articles/1443212_content.json
# JSON file saved at: ./data_processing/processed_articles/1443804_content.json
# JSON file saved at: ./data_processing/processed_articles/1445359_content.json
# JSON file saved at: ./data_processing/processed_articles/1445375_content.json
# JSON file saved at: ./data_processing/processed_articles/1445591_content.json
# JSON file saved at: ./data_processing/processed_articles/1442859_content.json
# JSON file saved at: ./data_processing/processed_articles/1444915_content.json
# JSON file saved at: ./data_processing/processed_articles/1442849_content.json
# JSON file saved at: ./data_processing/processed_articles/1444848_content.json
# JSON file saved at: ./data_processing/processed_articles/1444089_content.json
# JSON file saved at: ./data_processing/processed_articles/1446000_content.json
# JSON file saved at: ./data_processing/processed_articles/1442395_content.json
# JSON file saved at: ./data_processing/processed_articles/1443884_content.json
# JSON file saved at: ./data_processing/processed_articles/1444154_content.json
# JSON files saved at: ./data_processing/processed_articles/1445447_content.json and ./data_processing/processed_articles/1445447_table.json
# JSON file saved at: ./data_processing/processed_articles/1444353_content.json
# JSON file saved at: ./data_processing/processed_articles/1445809_content.json
# JSON file saved at: ./data_processing/processed_articles/1444035_content.json
# JSON file saved at: ./data_processing/processed_articles/1442719_content.json
# JSON files saved at: ./data_processing/processed_articles/1444056_content.json and ./data_processing/processed_articles/1444056_table.json
# JSON file saved at: ./data_processing/processed_articles/1444585_content.json
# JSON file saved at: ./data_processing/processed_articles/1444505_content.json
# JSON file saved at: ./data_processing/processed_articles/1442484_content.json
# JSON file saved at: ./data_processing/processed_articles/1442426_content.json
# JSON file saved at: ./data_processing/processed_articles/1443070_content.json
# JSON files saved at: ./data_processing/processed_articles/1442782_content.json and ./data_processing/processed_articles/1442782_table.json
# JSON file saved at: ./data_processing/processed_articles/1444451_content.json
# JSON file saved at: ./data_processing/processed_articles/1442997_content.json
# JSON file saved at: ./data_processing/processed_articles/1445302_content.json
# JSON file saved at: ./data_processing/processed_articles/1444393_content.json
# JSON file saved at: ./data_processing/processed_articles/1445908_content.json
# JSON files saved at: ./data_processing/processed_articles/1445144_content.json and ./data_processing/processed_articles/1445144_table.json
# JSON file saved at: ./data_processing/processed_articles/1444242_content.json
# JSON file saved at: ./data_processing/processed_articles/1445747_content.json
# JSON file saved at: ./data_processing/processed_articles/1445249_content.json
# JSON file saved at: ./data_processing/processed_articles/1446012_content.json
# JSON files saved at: ./data_processing/processed_articles/1443088_content.json and ./data_processing/processed_articles/1443088_table.json
# JSON file saved at: ./data_processing/processed_articles/1446072_content.json
# JSON file saved at: ./data_processing/processed_articles/1444797_content.json
# JSON files saved at: ./data_processing/processed_articles/1444565_content.json and ./data_processing/processed_articles/1444565_table.json
# JSON files saved at: ./data_processing/processed_articles/1444852_content.json and ./data_processing/processed_articles/1444852_table.json
# JSON file saved at: ./data_processing/processed_articles/1442436_content.json
# JSON file saved at: ./data_processing/processed_articles/1443705_content.json
# JSON files saved at: ./data_processing/processed_articles/1442686_content.json and ./data_processing/processed_articles/1442686_table.json
# JSON file saved at: ./data_processing/processed_articles/1442637_content.json
# JSON files saved at: ./data_processing/processed_articles/1445143_content.json and ./data_processing/processed_articles/1445143_table.json
# JSON files saved at: ./data_processing/processed_articles/1445899_content.json and ./data_processing/processed_articles/1445899_table.json
# JSON file saved at: ./data_processing/processed_articles/1445755_content.json
# JSON files saved at: ./data_processing/processed_articles/1443475_content.json and ./data_processing/processed_articles/1443475_table.json
# JSON file saved at: ./data_processing/processed_articles/1445512_content.json
# JSON file saved at: ./data_processing/processed_articles/1444944_content.json
# JSON file saved at: ./data_processing/processed_articles/1445090_content.json
# JSON file saved at: ./data_processing/processed_articles/1445837_content.json
# JSON file saved at: ./data_processing/processed_articles/1442466_content.json
# JSON file saved at: ./data_processing/processed_articles/1442452_content.json
# JSON files saved at: ./data_processing/processed_articles/1445147_content.json and ./data_processing/processed_articles/1445147_table.json
# JSON file saved at: ./data_processing/processed_articles/1443002_content.json
# JSON file saved at: ./data_processing/processed_articles/1442694_content.json
# JSON file saved at: ./data_processing/processed_articles/1446097_content.json
# JSON file saved at: ./data_processing/processed_articles/1445534_content.json
# JSON file saved at: ./data_processing/processed_articles/1445586_content.json
# JSON file saved at: ./data_processing/processed_articles/1442590_content.json
# JSON files saved at: ./data_processing/processed_articles/1445689_content.json and ./data_processing/processed_articles/1445689_table.json
# JSON file saved at: ./data_processing/processed_articles/1445686_content.json
# JSON file saved at: ./data_processing/processed_articles/1445980_content.json
# JSON file saved at: ./data_processing/processed_articles/1442530_content.json
# JSON file saved at: ./data_processing/processed_articles/1445881_content.json
# JSON file saved at: ./data_processing/processed_articles/1445947_content.json
# JSON file saved at: ./data_processing/processed_articles/1444895_content.json
# JSON file saved at: ./data_processing/processed_articles/1446060_content.json
# JSON file saved at: ./data_processing/processed_articles/1445906_content.json
# JSON file saved at: ./data_processing/processed_articles/1443650_content.json
# JSON file saved at: ./data_processing/processed_articles/1444503_content.json
# JSON file saved at: ./data_processing/processed_articles/1445942_content.json
# JSON file saved at: ./data_processing/processed_articles/1445946_content.json
# JSON file saved at: ./data_processing/processed_articles/1442608_content.json
# JSON file saved at: ./data_processing/processed_articles/1446021_content.json
# JSON file saved at: ./data_processing/processed_articles/1443130_content.json
# JSON files saved at: ./data_processing/processed_articles/1445859_content.json and ./data_processing/processed_articles/1445859_table.json
# JSON file saved at: ./data_processing/processed_articles/1445974_content.json
# JSON file saved at: ./data_processing/processed_articles/1443357_content.json
# JSON file saved at: ./data_processing/processed_articles/1445442_content.json
# JSON file saved at: ./data_processing/processed_articles/1445402_content.json
# JSON file saved at: ./data_processing/processed_articles/1445342_content.json
# JSON file saved at: ./data_processing/processed_articles/1444538_content.json
# JSON file saved at: ./data_processing/processed_articles/1443723_content.json
# JSON file saved at: ./data_processing/processed_articles/1443507_content.json
# JSON file saved at: ./data_processing/processed_articles/1446074_content.json
# JSON file saved at: ./data_processing/processed_articles/1443022_content.json
# JSON file saved at: ./data_processing/processed_articles/1443798_content.json
# JSON file saved at: ./data_processing/processed_articles/1444636_content.json
# JSON file saved at: ./data_processing/processed_articles/1445425_content.json
# JSON file saved at: ./data_processing/processed_articles/1445991_content.json
# JSON file saved at: ./data_processing/processed_articles/1442711_content.json
# JSON file saved at: ./data_processing/processed_articles/1445298_content.json
# JSON file saved at: ./data_processing/processed_articles/1443254_content.json
# JSON file saved at: ./data_processing/processed_articles/1443586_content.json
# JSON files saved at: ./data_processing/processed_articles/1445172_content.json and ./data_processing/processed_articles/1445172_table.json
# JSON file saved at: ./data_processing/processed_articles/1445320_content.json
# JSON file saved at: ./data_processing/processed_articles/1445998_content.json
# JSON file saved at: ./data_processing/processed_articles/1443171_content.json
# ...
# JSON file saved at: ./data_processing/processed_articles/1435077_content.json
# JSON file saved at: ./data_processing/processed_articles/1435088_content.json
# JSON file saved at: ./data_processing/processed_articles/1435078_content.json
# JSON file saved at: ./data_processing/processed_articles/1435163_content.json
# JSON file saved at: ./data_processing/processed_articles/1435212_content.json
# JSON file saved at: ./data_processing/processed_articles/1435263_content.json
# JSON file saved at: ./data_processing/processed_articles/1434965_content.json
# JSON file saved at: ./data_processing/processed_articles/1435255_content.json
# JSON file saved at: ./data_processing/processed_articles/1435355_content.json
# JSON file saved at: ./data_processing/processed_articles/1434793_content.json
# JSON file saved at: ./data_processing/processed_articles/1434897_content.json
# JSON file saved at: ./data_processing/processed_articles/1435087_content.json
# JSON file saved at: ./data_processing/processed_articles/1434750_content.json
# JSON file saved at: ./data_processing/processed_articles/1434861_content.json
# JSON file saved at: ./data_processing/processed_articles/1435275_content.json
# JSON file saved at: ./data_processing/processed_articles/1497058_content.json
# JSON file saved at: ./data_processing/processed_articles/1435201_content.json
# JSON file saved at: ./data_processing/processed_articles/1434969_content.json
# JSON file saved at: ./data_processing/processed_articles/1435073_content.json
# JSON file saved at: ./data_processing/processed_articles/1435149_content.json
# JSON file saved at: ./data_processing/processed_articles/1434785_content.json
# JSON file saved at: ./data_processing/processed_articles/1435195_content.json
# JSON file saved at: ./data_processing/processed_articles/1434869_content.json
# JSON file saved at: ./data_processing/processed_articles/1434959_content.json
# JSON file saved at: ./data_processing/processed_articles/1434961_content.json
# JSON file saved at: ./data_processing/processed_articles/1435233_content.json
# JSON file saved at: ./data_processing/processed_articles/1434763_content.json
# JSON file saved at: ./data_processing/processed_articles/1434771_content.json
# JSON file saved at: ./data_processing/processed_articles/1434773_content.json
# JSON file saved at: ./data_processing/processed_articles/1463424_content.json
# JSON file saved at: ./data_processing/processed_articles/1435101_content.json
# JSON file saved at: ./data_processing/processed_articles/1435068_content.json
# JSON file saved at: ./data_processing/processed_articles/1434933_content.json
# JSON file saved at: ./data_processing/processed_articles/1467163_content.json
# JSON file saved at: ./data_processing/processed_articles/1434955_content.json
# JSON file saved at: ./data_processing/processed_articles/1453427_content.json
# JSON file saved at: ./data_processing/processed_articles/1434977_content.json
# JSON file saved at: ./data_processing/processed_articles/1434859_content.json
# JSON file saved at: ./data_processing/processed_articles/1435265_content.json
# JSON file saved at: ./data_processing/processed_articles/1435261_content.json
# JSON file saved at: ./data_processing/processed_articles/1435105_content.json
# JSON file saved at: ./data_processing/processed_articles/1434951_content.json
# JSON file saved at: ./data_processing/processed_articles/1435273_content.json
# JSON file saved at: ./data_processing/processed_articles/1434767_content.json
# JSON file saved at: ./data_processing/processed_articles/1434749_content.json
# JSON file saved at: ./data_processing/processed_articles/1435251_content.json
# JSON file saved at: ./data_processing/processed_articles/1434812_content.json
# JSON file saved at: ./data_processing/processed_articles/1435187_content.json
# JSON file saved at: ./data_processing/processed_articles/1435176_content.json
# JSON file saved at: ./data_processing/processed_articles/1435103_content.json
# JSON file saved at: ./data_processing/processed_articles/1434745_content.json
# JSON file saved at: ./data_processing/processed_articles/1435155_content.json
# JSON file saved at: ./data_processing/processed_articles/1435179_content.json
# JSON file saved at: ./data_processing/processed_articles/1435191_content.json
# JSON file saved at: ./data_processing/processed_articles/1435095_content.json
# JSON file saved at: ./data_processing/processed_articles/1435067_content.json
# JSON file saved at: ./data_processing/processed_articles/1435360_content.json
# JSON file saved at: ./data_processing/processed_articles/1434953_content.json
# JSON file saved at: ./data_processing/processed_articles/1463427_content.json
# JSON file saved at: ./data_processing/processed_articles/1463426_content.json
# JSON file saved at: ./data_processing/processed_articles/1435199_content.json
# JSON file saved at: ./data_processing/processed_articles/1435269_content.json
# JSON file saved at: ./data_processing/processed_articles/1434838_content.json
# JSON file saved at: ./data_processing/processed_articles/1435196_content.json
# JSON file saved at: ./data_processing/processed_articles/1435116_content.json
# JSON file saved at: ./data_processing/processed_articles/1434883_content.json
# JSON file saved at: ./data_processing/processed_articles/1434971_content.json
# JSON file saved at: ./data_processing/processed_articles/1435271_content.json
# JSON file saved at: ./data_processing/processed_articles/1435048_content.json
# JSON file saved at: ./data_processing/processed_articles/1435047_content.json
# JSON file saved at: ./data_processing/processed_articles/1435219_content.json
# JSON file saved at: ./data_processing/processed_articles/1435099_content.json
# JSON file saved at: ./data_processing/processed_articles/1500502_content.json
# JSON file saved at: ./data_processing/processed_articles/1435109_content.json
# JSON file saved at: ./data_processing/processed_articles/1435113_content.json
# JSON file saved at: ./data_processing/processed_articles/1435120_content.json
# JSON file saved at: ./data_processing/processed_articles/1435193_content.json
# JSON file saved at: ./data_processing/processed_articles/1434877_content.json
# JSON file saved at: ./data_processing/processed_articles/1435111_content.json
# JSON file saved at: ./data_processing/processed_articles/1435169_content.json
# JSON file saved at: ./data_processing/processed_articles/1434980_content.json
# JSON file saved at: ./data_processing/processed_articles/1435278_content.json
# JSON file saved at: ./data_processing/processed_articles/1435227_content.json
# JSON file saved at: ./data_processing/processed_articles/1435208_content.json
# JSON file saved at: ./data_processing/processed_articles/1435252_content.json
# JSON file saved at: ./data_processing/processed_articles/1435267_content.json
# JSON file saved at: ./data_processing/processed_articles/1435277_content.json
# JSON files saved at: ./data_processing/processed_articles/1434823_content.json and ./data_processing/processed_articles/1434823_table.json
# JSON file saved at: ./data_processing/processed_articles/1434973_content.json
# JSON file saved at: ./data_processing/processed_articles/1434891_content.json
# JSON files saved at: ./data_processing/processed_articles/1434821_content.json and ./data_processing/processed_articles/1434821_table.json
# JSON file saved at: ./data_processing/processed_articles/1498711_content.json
# JSON file saved at: ./data_processing/processed_articles/1434879_content.json
# JSON file saved at: ./data_processing/processed_articles/1434990_content.json
# JSON file saved at: ./data_processing/processed_articles/1434783_content.json
# JSON file saved at: ./data_processing/processed_articles/1504038_content.json
# JSON file saved at: ./data_processing/processed_articles/1434819_content.json
# JSON file saved at: ./data_processing/processed_articles/1434787_content.json
# JSON file saved at: ./data_processing/processed_articles/1470195_content.json
# JSON file saved at: ./data_processing/processed_articles/1434825_content.json
# JSON file saved at: ./data_processing/processed_articles/1434781_content.json
# JSON file saved at: ./data_processing/processed_articles/1435091_content.json
# JSON files saved at: ./data_processing/processed_articles/1434867_content.json and ./data_processing/processed_articles/1434867_table.json
# JSON file saved at: ./data_processing/processed_articles/1435013_content.json
# JSON files saved at: ./data_processing/processed_articles/1434865_content.json and ./data_processing/processed_articles/1434865_table.json
# JSON file saved at: ./data_processing/processed_articles/1435023_content.json
# JSON file saved at: ./data_processing/processed_articles/1499999_content.json
# JSON file saved at: ./data_processing/processed_articles/1495910_content.json
# JSON file saved at: ./data_processing/processed_articles/1435325_content.json
# JSON file saved at: ./data_processing/processed_articles/1435315_content.json
# JSON file saved at: ./data_processing/processed_articles/1435291_content.json
# JSON files saved at: ./data_processing/processed_articles/1435313_content.json and ./data_processing/processed_articles/1435313_table.json
# JSON file saved at: ./data_processing/processed_articles/1435285_content.json
# JSON file saved at: ./data_processing/processed_articles/1435287_content.json
# JSON file saved at: ./data_processing/processed_articles/1435318_content.json
# JSON file saved at: ./data_processing/processed_articles/1435323_content.json
# JSON file saved at: ./data_processing/processed_articles/1435317_content.json
# JSON file saved at: ./data_processing/processed_articles/1435305_content.json
# JSON file saved at: ./data_processing/processed_articles/1435295_content.json
# JSON file saved at: ./data_processing/processed_articles/1435329_content.json
# JSON file saved at: ./data_processing/processed_articles/1435307_content.json
# JSON file saved at: ./data_processing/processed_articles/1435293_content.json
# JSON file saved at: ./data_processing/processed_articles/1435333_content.json
# JSON file saved at: ./data_processing/processed_articles/1435301_content.json
# JSON file saved at: ./data_processing/processed_articles/1435283_content.json
# JSON file saved at: ./data_processing/processed_articles/1435321_content.json
# JSON file saved at: ./data_processing/processed_articles/1435289_content.json
# JSON file saved at: ./data_processing/processed_articles/1435302_content.json
# JSON file saved at: ./data_processing/processed_articles/1435309_content.json
# JSON file saved at: ./data_processing/processed_articles/1476504_content.json
# JSON file saved at: ./data_processing/processed_articles/1435093_content.json
# JSON file saved at: ./data_processing/processed_articles/1434851_content.json
# JSON file saved at: ./data_processing/processed_articles/1501419_content.json
# JSON file saved at: ./data_processing/processed_articles/1465384_content.json
# JSON file saved at: ./data_processing/processed_articles/1434843_content.json
# JSON file saved at: ./data_processing/processed_articles/1482313_content.json
# JSON file saved at: ./data_processing/processed_articles/1435344_content.json
# JSON file saved at: ./data_processing/processed_articles/1434979_content.json
# JSON file saved at: ./data_processing/processed_articles/1434983_content.json
# JSON file saved at: ./data_processing/processed_articles/1435311_content.json
# JSON file saved at: ./data_processing/processed_articles/1434831_content.json
# JSON file saved at: ./data_processing/processed_articles/1434921_content.json
# JSON file saved at: ./data_processing/processed_articles/1434889_content.json
# JSON file saved at: ./data_processing/processed_articles/1434873_content.json
# JSON file saved at: ./data_processing/processed_articles/1434911_content.json
# JSON file saved at: ./data_processing/processed_articles/1434847_content.json
# JSON file saved at: ./data_processing/processed_articles/1434863_content.json
# JSON file saved at: ./data_processing/processed_articles/1435175_content.json
# JSON file saved at: ./data_processing/processed_articles/1435159_content.json
# JSON file saved at: ./data_processing/processed_articles/1435136_content.json
# JSON file saved at: ./data_processing/processed_articles/1474295_content.json
# JSON file saved at: ./data_processing/processed_articles/1435156_content.json
# JSON file saved at: ./data_processing/processed_articles/1435147_content.json
# JSON file saved at: ./data_processing/processed_articles/1435141_content.json
# JSON file saved at: ./data_processing/processed_articles/1435135_content.json
# JSON file saved at: ./data_processing/processed_articles/1435172_content.json
# JSON file saved at: ./data_processing/processed_articles/1435132_content.json
# JSON file saved at: ./data_processing/processed_articles/1435151_content.json
# JSON file saved at: ./data_processing/processed_articles/1435211_content.json
# JSON file saved at: ./data_processing/processed_articles/1435185_content.json
# JSON file saved at: ./data_processing/processed_articles/1468237_content.json
# JSON file saved at: ./data_processing/processed_articles/1435152_content.json
# JSON file saved at: ./data_processing/processed_articles/1482060_content.json
# JSON file saved at: ./data_processing/processed_articles/1468228_content.json
# JSON file saved at: ./data_processing/processed_articles/1435207_content.json
# JSON file saved at: ./data_processing/processed_articles/1435336_content.json
# JSON file saved at: ./data_processing/processed_articles/1435131_content.json
# JSON file saved at: ./data_processing/processed_articles/1435203_content.json
# JSON file saved at: ./data_processing/processed_articles/1434801_content.json
# JSON file saved at: ./data_processing/processed_articles/1435145_content.json
# JSON file saved at: ./data_processing/processed_articles/1434796_content.json
# JSON file saved at: ./data_processing/processed_articles/1435181_content.json
# JSON file saved at: ./data_processing/processed_articles/1435343_content.json
# JSON file saved at: ./data_processing/processed_articles/1470565_content.json
# JSON file saved at: ./data_processing/processed_articles/1435339_content.json
# JSON file saved at: ./data_processing/processed_articles/1435142_content.json
# JSON file saved at: ./data_processing/processed_articles/1434807_content.json
# JSON file saved at: ./data_processing/processed_articles/1435204_content.json
# JSON file saved at: ./data_processing/processed_articles/1435139_content.json
# JSON file saved at: ./data_processing/processed_articles/1435127_content.json
# JSON file saved at: ./data_processing/processed_articles/1435167_content.json
# JSON file saved at: ./data_processing/processed_articles/1468676_content.json
# JSON file saved at: ./data_processing/processed_articles/1435215_content.json
# JSON file saved at: ./data_processing/processed_articles/1434815_content.json
# JSON file saved at: ./data_processing/processed_articles/1440789_content.json
# JSON file saved at: ./data_processing/processed_articles/1440758_content.json
# JSON files saved at: ./data_processing/processed_articles/1440770_content.json and ./data_processing/processed_articles/1440770_table.json
# JSON file saved at: ./data_processing/processed_articles/1440797_content.json
# JSON file saved at: ./data_processing/processed_articles/1440793_content.json
# JSON file saved at: ./data_processing/processed_articles/1440776_content.json
# JSON files saved at: ./data_processing/processed_articles/1440759_content.json and ./data_processing/processed_articles/1440759_table.json
# JSON files saved at: ./data_processing/processed_articles/1440795_content.json and ./data_processing/processed_articles/1440795_table.json
# JSON file saved at: ./data_processing/processed_articles/1440774_content.json
# JSON file saved at: ./data_processing/processed_articles/1440763_content.json
# JSON file saved at: ./data_processing/processed_articles/1440791_content.json
# JSON file saved at: ./data_processing/processed_articles/1440768_content.json
# JSON file saved at: ./data_processing/processed_articles/1440766_content.json
# JSON file saved at: ./data_processing/processed_articles/1440762_content.json

# %% [markdown]
# #### Remove all .json files from a directory

# %%
def remove_json_files(directory):
    """
    Removes all .json files from the specified directory.

    Parameters:
    directory (str): The path to the directory where .json files are to be removed.
    """
    # Create the search pattern for .json files
    search_pattern = os.path.join(directory, "*.json")

    # Get a list of all .json files in the directory
    json_files = glob.glob(search_pattern)

    # Remove each .json file
    for file in json_files:
        os.remove(file)
        print(f"Removed file: {file}")


# Specify the directory where .json files are located
output_directory = "./data_processing/processed_articles"

# Call the function to remove .json files
remove_json_files(output_directory)
